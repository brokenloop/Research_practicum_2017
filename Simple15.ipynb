# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#Import statsmodels package for training a linear regression model.
import statsmodels.formula.api as sm

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-18a550fbce6f> in <module>()
#      21 from sklearn.linear_model import SGDClassifier
#      22 from sklearn.tree import DecisionTreeClassifier
# ---> 23 from sklearn.model_selection import train_test_split
#      24 from sklearn import metrics
#
# ImportError: No module named 'sklearn.model_selection'

# %% [markdown]
# # Import and Name Columns

# %%
#Read in the data from a csv file using Pandas
df = pd.read_csv("bus_data/cleaned_data/line15.csv", low_memory=False, header=None)
df.columns = ["Timestamp", "LineID", "Direction", "JourneyPatternID", "TimeFrame", 
              "VehicleJourneyID", "Operator", "Congestion", "Lon", "Lat", 
              "Delay", "BlockID", "VehicleID", "StopID", "AtStop"]

# %%
#Select all columns of type 'object'
object_columns = df.select_dtypes(['object']).columns

# %%
#Convert selected columns to type 'category'
for column in object_columns:
    df[column] = df[column].astype('category')

# %%
# Convert Unix timestamp to datetime

# Take uneccesary trailing zeroes off of unix timestamp. 
df['Timestamp'] = df['Timestamp'].apply(lambda x: x//1000000)

# Convert the timestamp
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')

# %%
# Add day of week column
df['Day'] = df['Timestamp'].dt.dayofweek

# %%
# Add hour of day column
df['Hour'] = df['Timestamp'].dt.hour

# %%
# Convert some features to categorical
for column in ['LineID', 'Direction','VehicleJourneyID', 'Congestion', 'BlockID', 'VehicleID', 'AtStop','Day','Hour']:
    df[column] = df[column].astype('category')

# %%
df = df.drop('BlockID', 1)
df = df.drop('Operator', 1)
df = df.drop('Delay', 1)
df = df.drop('Congestion', 1)

# %%
df = df.loc[df['JourneyPatternID'] == '00150001']

# %%
df.dtypes
# Out:
# Timestamp           datetime64[ns]
# LineID                    category
# Direction                 category
# JourneyPatternID          category
# TimeFrame                 category
# VehicleJourneyID          category
# Lon                        float64
# Lat                        float64
# VehicleID                 category
# StopID                    category
# AtStop                    category
# Day                       category
# Hour                      category
# dtype: object

# %%
df.shape
# Out:
# (607458, 13)

# %% [markdown]
# ### Continuous Columns

# %%
#Drop the duplicates, but keep the first occurance of when they occur
df = df.drop_duplicates(keep='first')

# %%
df.shape
# Out:
# (2254310, 13)

# %%
df.TimeFrame.nunique()
# Out:
# 26

# %%
df.TimeFrame.value_counts()
# Out:
# 2012-11-07    28406
# 2012-11-09    28215
# 2012-11-27    28075
# 2012-11-23    28039
# 2012-11-08    28016
# 2012-11-14    27946
# 2012-11-06    27805
# 2012-11-19    27772
# 2012-11-16    27553
# 2012-11-29    27500
# 2012-11-22    27452
# 2012-11-15    27393
# 2012-11-20    27342
# 2012-11-26    27264
# 2012-11-28    26797
# 2012-11-13    26564
# 2012-11-12    26488
# 2012-11-21    26394
# 2012-11-30    24179
# 2012-11-10    19086
# 2012-11-17    18784
# 2012-11-24    17595
# 2012-11-18    11262
# 2012-11-11    10744
# 2012-11-25    10673
# 2012-11-05      114
# Name: TimeFrame, dtype: int64

# %% [markdown]
# 33 columns dropped

# %%
for i in df.TimeFrame.unique():
    print(i)
# Out:
# 2012-11-05
# 2012-11-06
# 2012-11-07
# 2012-11-08
# 2012-11-09
# 2012-11-10
# 2012-11-11
# 2012-11-12
# 2012-11-13
# 2012-11-14
# 2012-11-15
# 2012-11-16
# 2012-11-17
# 2012-11-18
# 2012-11-19
# 2012-11-20
# 2012-11-21
# 2012-11-22
# 2012-11-23
# 2012-11-24
# 2012-11-25
# 2012-11-26
# 2012-11-27
# 2012-11-28
# 2012-11-29
# 2012-11-30

# %%
# durations = []

# for date in df.TimeFrame.unique():    
#     temp_df = df[(df.VehicleJourneyID == 5826) & (df.TimeFrame == date)]
    
#     duration = temp_df.Timestamp.max()-temp_df.Timestamp.min()

#     durations.append(duration)

# %%
# durations = []

# temp_df = df[df.TimeFrame.unique()[0]]

# inner_df = df[temp_dfdf.VehicleJourneyID == temp_df.VehicleJourneyID.unique()[0]]
    
# duration = inner_df.Timestamp.max()-inner_df.Timestamp.min()

# durations.append(duration)

# %%
# durations = []

# for date in df.TimeFrame.unique():    
#     temp_df = df[df.TimeFrame == date]
    
#     for journey in temp_df.VehicleJourneyID.unique():
        
#         inner_df = df[df.VehicleJourneyID == journey]
    
#         duration = inner_df.Timestamp.max()-inner_df.Timestamp.min()
#         durations.append(duration)

# %%
durations = []
columns = ['hour','day','duration']
rows = []

for date in df.TimeFrame.unique():    
    temp_df = df[df.TimeFrame == date]
    
    for journey in temp_df.VehicleJourneyID.unique():
        
        inner_df = temp_df[temp_df.VehicleJourneyID == journey]
        
        row = {}
    
        duration = inner_df.Timestamp.max()-inner_df.Timestamp.min()
        
        if (duration > datetime.timedelta(minutes=30)):
        
            row['hour'] = inner_df.Timestamp.min().hour
            row['day'] = inner_df.Timestamp.min().dayofweek
            row['duration'] = duration.seconds//60

            rows.append(row)

# %%
pp.pprint(rows)
# Out:
# [{'day': 1, 'duration': 105, 'hour': 6},
#  {'day': 1, 'duration': 92, 'hour': 6},
#  {'day': 1, 'duration': 93, 'hour': 6},
#  {'day': 1, 'duration': 94, 'hour': 6},
#  {'day': 1, 'duration': 148, 'hour': 6},
#  {'day': 1, 'duration': 96, 'hour': 6},
#  {'day': 1, 'duration': 108, 'hour': 6},
#  {'day': 1, 'duration': 107, 'hour': 7},
#  {'day': 1, 'duration': 107, 'hour': 7},
#  {'day': 1, 'duration': 103, 'hour': 7},
#  {'day': 1, 'duration': 106, 'hour': 7},
#  {'day': 1, 'duration': 117, 'hour': 7},
#  {'day': 1, 'duration': 112, 'hour': 7},
#  {'day': 1, 'duration': 115, 'hour': 8},
#  {'day': 1, 'duration': 108, 'hour': 8},
#  {'day': 1, 'duration': 110, 'hour': 8},
#  {'day': 1, 'duration': 109, 'hour': 8},
#  {'day': 1, 'duration': 106, 'hour': 8},
#  {'day': 1, 'duration': 104, 'hour': 8},
#  {'day': 1, 'duration': 106, 'hour': 9},
#  {'day': 1, 'duration': 107, 'hour': 9},
#  {'day': 1, 'duration': 103, 'hour': 9},
#  {'day': 1, 'duration': 107, 'hour': 9},
#  {'day': 1, 'duration': 94, 'hour': 9},
#  {'day': 1, 'duration': 94, 'hour': 9},
#  {'day': 1, 'duration': 96, 'hour': 10},
#  {'day': 1, 'duration': 100, 'hour': 10},
#  {'day': 1, 'duration': 100, 'hour': 10},
#  {'day': 1, 'duration': 97, 'hour': 10},
#  {'day': 1, 'duration': 96, 'hour': 10},
#  {'day': 1, 'duration': 102, 'hour': 10},
#  {'day': 1, 'duration': 94, 'hour': 11},
#  {'day': 1, 'duration': 97, 'hour': 11},
#  {'day': 1, 'duration': 97, 'hour': 11},
#  {'day': 1, 'duration': 94, 'hour': 11},
#  {'day': 1, 'duration': 100, 'hour': 11},
#  {'day': 1, 'duration': 102, 'hour': 11},
#  {'day': 1, 'duration': 94, 'hour': 12},
#  {'day': 1, 'duration': 99, 'hour': 12},
#  {'day': 1, 'duration': 103, 'hour': 12},
#  {'day': 1, 'duration': 93, 'hour': 12},
#  {'day': 1, 'duration': 95, 'hour': 12},
#  {'day': 1, 'duration': 93, 'hour': 13},
#  {'day': 1, 'duration': 96, 'hour': 13},
#  {'day': 1, 'duration': 96, 'hour': 13},
#  {'day': 1, 'duration': 100, 'hour': 13},
#  {'day': 1, 'duration': 96, 'hour': 13},
#  {'day': 1, 'duration': 98, 'hour': 13},
#  {'day': 1, 'duration': 95, 'hour': 13},
#  {'day': 1, 'duration': 93, 'hour': 14},
#  {'day': 1, 'duration': 106, 'hour': 14},
#  {'day': 1, 'duration': 92, 'hour': 14},
#  {'day': 1, 'duration': 95, 'hour': 14},
#  {'day': 1, 'duration': 87, 'hour': 14},
#  {'day': 1, 'duration': 97, 'hour': 14},
#  {'day': 1, 'duration': 103, 'hour': 15},
#  {'day': 1, 'duration': 105, 'hour': 15},
#  {'day': 1, 'duration': 104, 'hour': 15},
#  {'day': 1, 'duration': 105, 'hour': 15},
#  {'day': 1, 'duration': 107, 'hour': 15},
#  {'day': 1, 'duration': 108, 'hour': 15},
#  {'day': 1, 'duration': 103, 'hour': 16},
#  {'day': 1, 'duration': 109, 'hour': 16},
#  {'day': 1, 'duration': 111, 'hour': 16},
#  {'day': 1, 'duration': 104, 'hour': 16},
#  {'day': 1, 'duration': 113, 'hour': 16},
#  {'day': 1, 'duration': 104, 'hour': 16},
#  {'day': 1, 'duration': 114, 'hour': 16},
#  {'day': 1, 'duration': 108, 'hour': 17},
#  {'day': 1, 'duration': 115, 'hour': 17},
#  {'day': 1, 'duration': 102, 'hour': 17},
#  {'day': 1, 'duration': 109, 'hour': 17},
#  {'day': 1, 'duration': 101, 'hour': 17},
#  {'day': 1, 'duration': 111, 'hour': 18},
#  {'day': 1, 'duration': 112, 'hour': 18},
#  {'day': 1, 'duration': 111, 'hour': 18},
#  {'day': 1, 'duration': 98, 'hour': 18},
#  {'day': 1, 'duration': 97, 'hour': 18},
#  {'day': 1, 'duration': 115, 'hour': 18},
#  {'day': 1, 'duration': 89, 'hour': 19},
#  {'day': 1, 'duration': 95, 'hour': 19},
#  {'day': 1, 'duration': 67, 'hour': 19},
#  {'day': 1, 'duration': 96, 'hour': 19},
#  {'day': 1, 'duration': 94, 'hour': 20},
#  {'day': 1, 'duration': 99, 'hour': 20},
#  {'day': 1, 'duration': 98, 'hour': 20},
#  {'day': 1, 'duration': 94, 'hour': 21},
#  {'day': 1, 'duration': 92, 'hour': 21},
#  {'day': 1, 'duration': 118, 'hour': 21},
#  {'day': 1, 'duration': 83, 'hour': 22},
#  {'day': 1, 'duration': 78, 'hour': 22},
#  {'day': 1, 'duration': 89, 'hour': 23},
#  {'day': 2, 'duration': 96, 'hour': 6},
#  {'day': 2, 'duration': 93, 'hour': 6},
#  {'day': 2, 'duration': 105, 'hour': 6},
#  {'day': 2, 'duration': 92, 'hour': 6},
#  {'day': 2, 'duration': 91, 'hour': 6},
#  {'day': 2, 'duration': 95, 'hour': 6},
#  {'day': 2, 'duration': 107, 'hour': 6},
#  {'day': 2, 'duration': 109, 'hour': 7},
#  {'day': 2, 'duration': 100, 'hour': 7},
#  {'day': 2, 'duration': 137, 'hour': 7},
#  {'day': 2, 'duration': 102, 'hour': 7},
#  {'day': 2, 'duration': 116, 'hour': 7},
#  {'day': 2, 'duration': 114, 'hour': 7},
#  {'day': 2, 'duration': 112, 'hour': 8},
#  {'day': 2, 'duration': 116, 'hour': 8},
#  {'day': 2, 'duration': 111, 'hour': 8},
#  {'day': 2, 'duration': 103, 'hour': 8},
#  {'day': 2, 'duration': 109, 'hour': 8},
#  {'day': 2, 'duration': 103, 'hour': 9},
#  {'day': 2, 'duration': 106, 'hour': 9},
#  {'day': 2, 'duration': 106, 'hour': 9},
#  {'day': 2, 'duration': 111, 'hour': 9},
#  {'day': 2, 'duration': 105, 'hour': 9},
#  {'day': 2, 'duration': 98, 'hour': 9},
#  {'day': 2, 'duration': 97, 'hour': 9},
#  {'day': 2, 'duration': 97, 'hour': 10},
#  {'day': 2, 'duration': 97, 'hour': 10},
#  {'day': 2, 'duration': 97, 'hour': 10},
#  {'day': 2, 'duration': 97, 'hour': 10},
#  {'day': 2, 'duration': 105, 'hour': 10},
#  {'day': 2, 'duration': 96, 'hour': 10},
#  {'day': 2, 'duration': 89, 'hour': 11},
#  {'day': 2, 'duration': 95, 'hour': 11},
#  {'day': 2, 'duration': 96, 'hour': 11},
#  {'day': 2, 'duration': 95, 'hour': 11},
#  {'day': 2, 'duration': 96, 'hour': 11},
#  {'day': 2, 'duration': 94, 'hour': 11},
#  {'day': 2, 'duration': 99, 'hour': 12},
#  {'day': 2, 'duration': 97, 'hour': 12},
#  {'day': 2, 'duration': 102, 'hour': 12},
#  {'day': 2, 'duration': 96, 'hour': 12},
#  {'day': 2, 'duration': 102, 'hour': 12},
#  {'day': 2, 'duration': 93, 'hour': 13},
#  {'day': 2, 'duration': 102, 'hour': 13},
#  {'day': 2, 'duration': 107, 'hour': 13},
#  {'day': 2, 'duration': 99, 'hour': 13},
#  {'day': 2, 'duration': 95, 'hour': 13},
#  {'day': 2, 'duration': 96, 'hour': 13},
#  {'day': 2, 'duration': 97, 'hour': 13},
#  {'day': 2, 'duration': 91, 'hour': 14},
#  {'day': 2, 'duration': 102, 'hour': 14},
#  {'day': 2, 'duration': 100, 'hour': 14},
#  {'day': 2, 'duration': 94, 'hour': 14},
#  {'day': 2, 'duration': 95, 'hour': 14},
#  {'day': 2, 'duration': 98, 'hour': 14},
#  {'day': 2, 'duration': 104, 'hour': 15},
#  {'day': 2, 'duration': 105, 'hour': 15},
#  {'day': 2, 'duration': 104, 'hour': 15},
#  {'day': 2, 'duration': 106, 'hour': 15},
#  {'day': 2, 'duration': 106, 'hour': 15},
#  {'day': 2, 'duration': 101, 'hour': 15},
#  {'day': 2, 'duration': 104, 'hour': 16},
#  {'day': 2, 'duration': 118, 'hour': 16},
#  {'day': 2, 'duration': 127, 'hour': 16},
#  {'day': 2, 'duration': 111, 'hour': 16},
#  {'day': 2, 'duration': 254, 'hour': 16},
#  {'day': 2, 'duration': 112, 'hour': 16},
#  {'day': 2, 'duration': 107, 'hour': 16},
#  {'day': 2, 'duration': 121, 'hour': 17},
#  {'day': 2, 'duration': 118, 'hour': 17},
#  {'day': 2, 'duration': 107, 'hour': 17},
#  {'day': 2, 'duration': 92, 'hour': 17},
#  {'day': 2, 'duration': 108, 'hour': 17},
#  {'day': 2, 'duration': 107, 'hour': 18},
#  {'day': 2, 'duration': 107, 'hour': 18},
#  {'day': 2, 'duration': 67, 'hour': 18},
#  {'day': 2, 'duration': 110, 'hour': 18},
#  {'day': 2, 'duration': 102, 'hour': 18},
#  {'day': 2, 'duration': 120, 'hour': 18},
#  {'day': 2, 'duration': 93, 'hour': 19},
#  {'day': 2, 'duration': 97, 'hour': 19},
#  {'day': 2, 'duration': 96, 'hour': 19},
#  {'day': 2, 'duration': 94, 'hour': 20},
#  {'day': 2, 'duration': 104, 'hour': 20},
#  {'day': 2, 'duration': 64, 'hour': 20},
#  {'day': 2, 'duration': 106, 'hour': 20},
#  {'day': 2, 'duration': 101, 'hour': 21},
#  {'day': 2, 'duration': 93, 'hour': 21},
#  {'day': 2, 'duration': 96, 'hour': 21},
#  {'day': 2, 'duration': 83, 'hour': 22},
#  {'day': 2, 'duration': 86, 'hour': 22},
#  {'day': 2, 'duration': 91, 'hour': 22},
#  {'day': 3, 'duration': 96, 'hour': 6},
#  {'day': 3, 'duration': 93, 'hour': 6},
#  {'day': 3, 'duration': 93, 'hour': 6},
#  {'day': 3, 'duration': 97, 'hour': 6},
#  {'day': 3, 'duration': 79, 'hour': 6},
#  {'day': 3, 'duration': 99, 'hour': 6},
#  {'day': 3, 'duration': 106, 'hour': 6},
#  {'day': 3, 'duration': 106, 'hour': 7},
#  {'day': 3, 'duration': 100, 'hour': 7},
#  {'day': 3, 'duration': 108, 'hour': 7},
#  {'day': 3, 'duration': 102, 'hour': 7},
#  {'day': 3, 'duration': 117, 'hour': 7},
#  {'day': 3, 'duration': 114, 'hour': 7},
#  {'day': 3, 'duration': 113, 'hour': 8},
#  {'day': 3, 'duration': 108, 'hour': 8},
#  {'day': 3, 'duration': 119, 'hour': 8},
#  {'day': 3, 'duration': 114, 'hour': 8},
#  {'day': 3, 'duration': 109, 'hour': 8},
#  {'day': 3, 'duration': 109, 'hour': 8},
#  {'day': 3, 'duration': 103, 'hour': 9},
#  {'day': 3, 'duration': 105, 'hour': 9},
#  {'day': 3, 'duration': 110, 'hour': 9},
#  {'day': 3, 'duration': 105, 'hour': 9},
#  {'day': 3, 'duration': 103, 'hour': 9},
#  {'day': 3, 'duration': 94, 'hour': 10},
#  {'day': 3, 'duration': 99, 'hour': 10},
#  {'day': 3, 'duration': 97, 'hour': 10},
#  {'day': 3, 'duration': 98, 'hour': 10},
#  {'day': 3, 'duration': 98, 'hour': 10},
#  {'day': 3, 'duration': 97, 'hour': 10},
#  {'day': 3, 'duration': 97, 'hour': 10},
#  {'day': 3, 'duration': 102, 'hour': 11},
#  {'day': 3, 'duration': 95, 'hour': 11},
#  {'day': 3, 'duration': 117, 'hour': 11},
#  {'day': 3, 'duration': 92, 'hour': 11},
#  {'day': 3, 'duration': 94, 'hour': 11},
#  {'day': 3, 'duration': 95, 'hour': 11},
#  {'day': 3, 'duration': 95, 'hour': 12},
#  {'day': 3, 'duration': 92, 'hour': 12},
#  {'day': 3, 'duration': 102, 'hour': 12},
#  {'day': 3, 'duration': 94, 'hour': 12},
#  {'day': 3, 'duration': 99, 'hour': 12},
#  {'day': 3, 'duration': 96, 'hour': 12},
#  {'day': 3, 'duration': 100, 'hour': 13},
#  {'day': 3, 'duration': 96, 'hour': 13},
#  {'day': 3, 'duration': 114, 'hour': 13},
#  {'day': 3, 'duration': 94, 'hour': 13},
#  {'day': 3, 'duration': 96, 'hour': 13},
#  {'day': 3, 'duration': 96, 'hour': 13},
#  {'day': 3, 'duration': 94, 'hour': 14},
#  {'day': 3, 'duration': 98, 'hour': 14},
#  {'day': 3, 'duration': 135, 'hour': 14},
#  {'day': 3, 'duration': 94, 'hour': 14},
#  {'day': 3, 'duration': 94, 'hour': 14},
#  {'day': 3, 'duration': 108, 'hour': 15},
#  {'day': 3, 'duration': 109, 'hour': 15},
#  {'day': 3, 'duration': 109, 'hour': 15},
#  {'day': 3, 'duration': 105, 'hour': 15},
#  {'day': 3, 'duration': 108, 'hour': 15},
#  {'day': 3, 'duration': 110, 'hour': 15},
#  {'day': 3, 'duration': 103, 'hour': 16},
#  {'day': 3, 'duration': 110, 'hour': 16},
#  {'day': 3, 'duration': 109, 'hour': 16},
#  {'day': 3, 'duration': 106, 'hour': 16},
#  {'day': 3, 'duration': 108, 'hour': 16},
#  {'day': 3, 'duration': 106, 'hour': 16},
#  {'day': 3, 'duration': 110, 'hour': 16},
#  {'day': 3, 'duration': 109, 'hour': 17},
#  {'day': 3, 'duration': 117, 'hour': 17},
#  {'day': 3, 'duration': 104, 'hour': 17},
#  {'day': 3, 'duration': 102, 'hour': 17},
#  {'day': 3, 'duration': 105, 'hour': 17},
#  {'day': 3, 'duration': 113, 'hour': 18},
#  {'day': 3, 'duration': 97, 'hour': 18},
#  {'day': 3, 'duration': 108, 'hour': 18},
#  {'day': 3, 'duration': 114, 'hour': 18},
#  {'day': 3, 'duration': 66, 'hour': 18},
#  {'day': 3, 'duration': 121, 'hour': 18},
#  {'day': 3, 'duration': 91, 'hour': 19},
#  {'day': 3, 'duration': 92, 'hour': 19},
#  {'day': 3, 'duration': 96, 'hour': 19},
#  {'day': 3, 'duration': 91, 'hour': 19},
#  {'day': 3, 'duration': 105, 'hour': 20},
#  {'day': 3, 'duration': 98, 'hour': 20},
#  {'day': 3, 'duration': 98, 'hour': 20},
#  {'day': 3, 'duration': 94, 'hour': 21},
#  {'day': 3, 'duration': 92, 'hour': 21},
#  {'day': 3, 'duration': 96, 'hour': 21},
#  {'day': 3, 'duration': 86, 'hour': 22},
#  {'day': 3, 'duration': 86, 'hour': 22},
#  {'day': 3, 'duration': 97, 'hour': 23},
#  {'day': 4, 'duration': 99, 'hour': 6},
#  {'day': 4, 'duration': 97, 'hour': 6},
#  {'day': 4, 'duration': 98, 'hour': 6},
#  {'day': 4, 'duration': 96, 'hour': 6},
#  {'day': 4, 'duration': 91, 'hour': 6},
#  {'day': 4, 'duration': 104, 'hour': 6},
#  {'day': 4, 'duration': 108, 'hour': 6},
#  {'day': 4, 'duration': 107, 'hour': 7},
#  {'day': 4, 'duration': 101, 'hour': 7},
#  {'day': 4, 'duration': 105, 'hour': 7},
#  {'day': 4, 'duration': 103, 'hour': 7},
#  {'day': 4, 'duration': 114, 'hour': 7},
#  {'day': 4, 'duration': 101, 'hour': 7},
#  {'day': 4, 'duration': 107, 'hour': 8},
#  {'day': 4, 'duration': 112, 'hour': 8},
#  {'day': 4, 'duration': 113, 'hour': 8},
#  {'day': 4, 'duration': 125, 'hour': 8},
#  {'day': 4, 'duration': 104, 'hour': 8},
#  {'day': 4, 'duration': 102, 'hour': 9},
#  {'day': 4, 'duration': 100, 'hour': 9},
#  {'day': 4, 'duration': 103, 'hour': 9},
#  {'day': 4, 'duration': 45, 'hour': 9},
#  {'day': 4, 'duration': 105, 'hour': 9},
#  {'day': 4, 'duration': 98, 'hour': 9},
#  {'day': 4, 'duration': 95, 'hour': 10},
#  {'day': 4, 'duration': 94, 'hour': 10},
#  {'day': 4, 'duration': 92, 'hour': 10},
#  {'day': 4, 'duration': 98, 'hour': 10},
#  {'day': 4, 'duration': 94, 'hour': 10},
#  {'day': 4, 'duration': 97, 'hour': 10},
#  {'day': 4, 'duration': 99, 'hour': 10},
#  {'day': 4, 'duration': 104, 'hour': 11},
#  {'day': 4, 'duration': 93, 'hour': 11},
#  {'day': 4, 'duration': 104, 'hour': 11},
#  {'day': 4, 'duration': 97, 'hour': 11},
#  {'day': 4, 'duration': 96, 'hour': 11},
#  {'day': 4, 'duration': 101, 'hour': 11},
#  {'day': 4, 'duration': 99, 'hour': 12},
#  {'day': 4, 'duration': 91, 'hour': 12},
#  {'day': 4, 'duration': 104, 'hour': 12},
#  {'day': 4, 'duration': 97, 'hour': 12},
#  {'day': 4, 'duration': 98, 'hour': 12},
#  {'day': 4, 'duration': 96, 'hour': 12},
#  {'day': 4, 'duration': 93, 'hour': 13},
#  {'day': 4, 'duration': 96, 'hour': 13},
#  {'day': 4, 'duration': 96, 'hour': 13},
#  {'day': 4, 'duration': 102, 'hour': 13},
#  {'day': 4, 'duration': 107, 'hour': 13},
#  {'day': 4, 'duration': 94, 'hour': 14},
#  {'day': 4, 'duration': 136, 'hour': 14},
#  {'day': 4, 'duration': 93, 'hour': 14},
#  {'day': 4, 'duration': 93, 'hour': 14},
#  {'day': 4, 'duration': 93, 'hour': 14},
#  {'day': 4, 'duration': 99, 'hour': 14},
#  {'day': 4, 'duration': 106, 'hour': 15},
#  {'day': 4, 'duration': 105, 'hour': 15},
#  {'day': 4, 'duration': 105, 'hour': 15},
#  {'day': 4, 'duration': 105, 'hour': 15},
#  {'day': 4, 'duration': 115, 'hour': 15},
#  {'day': 4, 'duration': 102, 'hour': 15},
#  {'day': 4, 'duration': 101, 'hour': 16},
#  {'day': 4, 'duration': 123, 'hour': 16},
#  {'day': 4, 'duration': 139, 'hour': 16},
#  {'day': 4, 'duration': 118, 'hour': 16},
#  {'day': 4, 'duration': 155, 'hour': 16},
#  {'day': 4, 'duration': 103, 'hour': 16},
#  {'day': 4, 'duration': 110, 'hour': 16},
#  {'day': 4, 'duration': 109, 'hour': 17},
#  {'day': 4, 'duration': 116, 'hour': 17},
#  {'day': 4, 'duration': 103, 'hour': 17},
#  {'day': 4, 'duration': 108, 'hour': 17},
#  {'day': 4, 'duration': 103, 'hour': 17},
#  {'day': 4, 'duration': 103, 'hour': 18},
#  {'day': 4, 'duration': 111, 'hour': 18},
#  {'day': 4, 'duration': 106, 'hour': 18},
#  {'day': 4, 'duration': 111, 'hour': 18},
#  {'day': 4, 'duration': 98, 'hour': 18},
#  {'day': 4, 'duration': 119, 'hour': 18},
#  {'day': 4, 'duration': 100, 'hour': 19},
#  {'day': 4, 'duration': 93, 'hour': 19},
#  {'day': 4, 'duration': 95, 'hour': 19},
#  {'day': 4, 'duration': 100, 'hour': 20},
#  {'day': 4, 'duration': 96, 'hour': 20},
#  {'day': 4, 'duration': 98, 'hour': 20},
#  {'day': 4, 'duration': 104, 'hour': 20},
#  {'day': 4, 'duration': 94, 'hour': 21},
#  {'day': 4, 'duration': 93, 'hour': 21},
#  {'day': 4, 'duration': 91, 'hour': 21},
#  {'day': 4, 'duration': 91, 'hour': 22},
#  {'day': 4, 'duration': 99, 'hour': 22},
#  {'day': 4, 'duration': 91, 'hour': 22},
#  {'day': 5, 'duration': 102, 'hour': 6},
#  {'day': 5, 'duration': 96, 'hour': 6},
#  {'day': 5, 'duration': 97, 'hour': 6},
#  {'day': 5, 'duration': 98, 'hour': 7},
#  {'day': 5, 'duration': 101, 'hour': 7},
#  {'day': 5, 'duration': 101, 'hour': 7},
#  {'day': 5, 'duration': 104, 'hour': 7},
#  {'day': 5, 'duration': 96, 'hour': 8},
#  {'day': 5, 'duration': 114, 'hour': 8},
#  {'day': 5, 'duration': 97, 'hour': 8},
#  {'day': 5, 'duration': 109, 'hour': 8},
#  {'day': 5, 'duration': 104, 'hour': 9},
#  {'day': 5, 'duration': 100, 'hour': 9},
#  {'day': 5, 'duration': 104, 'hour': 9},
#  {'day': 5, 'duration': 104, 'hour': 9},
#  {'day': 5, 'duration': 108, 'hour': 10},
#  {'day': 5, 'duration': 103, 'hour': 10},
#  {'day': 5, 'duration': 104, 'hour': 10},
#  {'day': 5, 'duration': 103, 'hour': 10},
#  {'day': 5, 'duration': 103, 'hour': 11},
#  {'day': 5, 'duration': 103, 'hour': 11},
#  {'day': 5, 'duration': 100, 'hour': 11},
#  {'day': 5, 'duration': 97, 'hour': 12},
#  {'day': 5, 'duration': 105, 'hour': 12},
#  {'day': 5, 'duration': 103, 'hour': 12},
#  {'day': 5, 'duration': 102, 'hour': 12},
#  {'day': 5, 'duration': 98, 'hour': 13},
#  {'day': 5, 'duration': 100, 'hour': 13},
#  {'day': 5, 'duration': 101, 'hour': 13},
#  {'day': 5, 'duration': 104, 'hour': 13},
#  {'day': 5, 'duration': 100, 'hour': 13},
#  {'day': 5, 'duration': 102, 'hour': 14},
#  {'day': 5, 'duration': 100, 'hour': 14},
#  {'day': 5, 'duration': 103, 'hour': 14},
#  {'day': 5, 'duration': 107, 'hour': 14},
#  {'day': 5, 'duration': 102, 'hour': 15},
#  {'day': 5, 'duration': 92, 'hour': 15},
#  {'day': 5, 'duration': 97, 'hour': 15},
#  {'day': 5, 'duration': 101, 'hour': 15},
#  {'day': 5, 'duration': 97, 'hour': 16},
#  {'day': 5, 'duration': 103, 'hour': 16},
#  {'day': 5, 'duration': 99, 'hour': 16},
#  {'day': 5, 'duration': 93, 'hour': 17},
#  {'day': 5, 'duration': 98, 'hour': 17},
#  {'day': 5, 'duration': 104, 'hour': 17},
#  {'day': 5, 'duration': 96, 'hour': 17},
#  {'day': 5, 'duration': 97, 'hour': 18},
#  {'day': 5, 'duration': 74, 'hour': 18},
#  {'day': 5, 'duration': 93, 'hour': 18},
#  {'day': 5, 'duration': 104, 'hour': 19},
#  {'day': 5, 'duration': 96, 'hour': 19},
#  {'day': 5, 'duration': 94, 'hour': 19},
#  {'day': 5, 'duration': 103, 'hour': 19},
#  {'day': 5, 'duration': 96, 'hour': 20},
#  {'day': 5, 'duration': 102, 'hour': 20},
#  {'day': 5, 'duration': 96, 'hour': 20},
#  {'day': 5, 'duration': 104, 'hour': 20},
#  {'day': 5, 'duration': 94, 'hour': 20},
#  {'day': 5, 'duration': 103, 'hour': 21},
#  {'day': 5, 'duration': 93, 'hour': 21},
#  {'day': 5, 'duration': 97, 'hour': 22},
#  {'day': 5, 'duration': 132, 'hour': 22},
#  {'day': 5, 'duration': 87, 'hour': 22},
#  {'day': 5, 'duration': 87, 'hour': 23},
#  {'day': 6, 'duration': 80, 'hour': 8},
#  {'day': 6, 'duration': 80, 'hour': 9},
#  {'day': 6, 'duration': 79, 'hour': 9},
#  {'day': 6, 'duration': 77, 'hour': 9},
#  {'day': 6, 'duration': 80, 'hour': 10},
#  {'day': 6, 'duration': 77, 'hour': 10},
#  {'day': 6, 'duration': 95, 'hour': 10},
#  {'day': 6, 'duration': 95, 'hour': 11},
#  {'day': 6, 'duration': 92, 'hour': 11},
#  {'day': 6, 'duration': 95, 'hour': 11},
#  {'day': 6, 'duration': 99, 'hour': 12},
#  {'day': 6, 'duration': 101, 'hour': 12},
#  {'day': 6, 'duration': 113, 'hour': 12},
#  {'day': 6, 'duration': 93, 'hour': 13},
#  {'day': 6, 'duration': 96, 'hour': 13},
#  {'day': 6, 'duration': 96, 'hour': 13},
#  {'day': 6, 'duration': 96, 'hour': 14},
#  {'day': 6, 'duration': 95, 'hour': 14},
#  {'day': 6, 'duration': 96, 'hour': 14},
#  {'day': 6, 'duration': 90, 'hour': 15},
#  {'day': 6, 'duration': 99, 'hour': 15},
#  {'day': 6, 'duration': 99, 'hour': 15},
#  {'day': 6, 'duration': 97, 'hour': 16},
#  {'day': 6, 'duration': 101, 'hour': 16},
#  {'day': 6, 'duration': 95, 'hour': 16},
#  {'day': 6, 'duration': 91, 'hour': 17},
#  {'day': 6, 'duration': 114, 'hour': 17},
#  {'day': 6, 'duration': 90, 'hour': 17},
#  {'day': 6, 'duration': 98, 'hour': 18},
#  {'day': 6, 'duration': 72, 'hour': 18},
#  {'day': 6, 'duration': 93, 'hour': 18},
#  {'day': 6, 'duration': 80, 'hour': 19},
#  {'day': 6, 'duration': 92, 'hour': 19},
#  {'day': 6, 'duration': 89, 'hour': 20},
#  {'day': 6, 'duration': 86, 'hour': 20},
#  {'day': 6, 'duration': 54, 'hour': 21},
#  {'day': 6, 'duration': 78, 'hour': 21},
#  {'day': 6, 'duration': 87, 'hour': 22},
#  {'day': 6, 'duration': 87, 'hour': 22},
#  {'day': 0, 'duration': 101, 'hour': 6},
#  {'day': 0, 'duration': 100, 'hour': 6},
#  {'day': 0, 'duration': 92, 'hour': 6},
#  {'day': 0, 'duration': 109, 'hour': 6},
#  {'day': 0, 'duration': 109, 'hour': 6},
#  {'day': 0, 'duration': 93, 'hour': 6},
#  {'day': 0, 'duration': 109, 'hour': 6},
#  {'day': 0, 'duration': 108, 'hour': 7},
#  {'day': 0, 'duration': 102, 'hour': 7},
#  {'day': 0, 'duration': 114, 'hour': 7},
#  {'day': 0, 'duration': 103, 'hour': 7},
#  {'day': 0, 'duration': 110, 'hour': 7},
#  {'day': 0, 'duration': 120, 'hour': 7},
#  {'day': 0, 'duration': 105, 'hour': 8},
#  {'day': 0, 'duration': 111, 'hour': 8},
#  {'day': 0, 'duration': 113, 'hour': 8},
#  {'day': 0, 'duration': 109, 'hour': 8},
#  {'day': 0, 'duration': 103, 'hour': 8},
#  {'day': 0, 'duration': 105, 'hour': 9},
#  {'day': 0, 'duration': 109, 'hour': 9},
#  {'day': 0, 'duration': 103, 'hour': 9},
#  {'day': 0, 'duration': 102, 'hour': 9},
#  {'day': 0, 'duration': 119, 'hour': 9},
#  {'day': 0, 'duration': 97, 'hour': 9},
#  {'day': 0, 'duration': 97, 'hour': 10},
#  {'day': 0, 'duration': 96, 'hour': 10},
#  {'day': 0, 'duration': 107, 'hour': 10},
#  {'day': 0, 'duration': 97, 'hour': 10},
#  {'day': 0, 'duration': 96, 'hour': 10},
#  {'day': 0, 'duration': 97, 'hour': 10},
#  {'day': 0, 'duration': 96, 'hour': 11},
#  {'day': 0, 'duration': 96, 'hour': 11},
#  {'day': 0, 'duration': 68, 'hour': 11},
#  {'day': 0, 'duration': 94, 'hour': 11},
#  {'day': 0, 'duration': 97, 'hour': 11},
#  {'day': 0, 'duration': 102, 'hour': 11},
#  {'day': 0, 'duration': 100, 'hour': 12},
#  {'day': 0, 'duration': 94, 'hour': 12},
#  {'day': 0, 'duration': 94, 'hour': 12},
#  {'day': 0, 'duration': 96, 'hour': 12},
#  {'day': 0, 'duration': 100, 'hour': 12},
#  {'day': 0, 'duration': 95, 'hour': 13},
#  {'day': 0, 'duration': 101, 'hour': 13},
#  {'day': 0, 'duration': 93, 'hour': 13},
#  {'day': 0, 'duration': 94, 'hour': 13},
#  {'day': 0, 'duration': 99, 'hour': 13},
#  {'day': 0, 'duration': 93, 'hour': 14},
#  {'day': 0, 'duration': 99, 'hour': 14},
#  {'day': 0, 'duration': 100, 'hour': 14},
#  {'day': 0, 'duration': 93, 'hour': 14},
#  {'day': 0, 'duration': 101, 'hour': 14},
#  {'day': 0, 'duration': 97, 'hour': 14},
#  {'day': 0, 'duration': 104, 'hour': 14},
#  {'day': 0, 'duration': 103, 'hour': 15},
#  {'day': 0, 'duration': 103, 'hour': 15},
#  {'day': 0, 'duration': 110, 'hour': 15},
#  {'day': 0, 'duration': 103, 'hour': 15},
#  {'day': 0, 'duration': 103, 'hour': 16},
#  {'day': 0, 'duration': 104, 'hour': 16},
#  {'day': 0, 'duration': 111, 'hour': 16},
#  {'day': 0, 'duration': 103, 'hour': 16},
#  {'day': 0, 'duration': 110, 'hour': 16},
#  {'day': 0, 'duration': 107, 'hour': 16},
#  {'day': 0, 'duration': 109, 'hour': 16},
#  {'day': 0, 'duration': 111, 'hour': 17},
#  {'day': 0, 'duration': 118, 'hour': 17},
#  {'day': 0, 'duration': 105, 'hour': 17},
#  {'day': 0, 'duration': 109, 'hour': 17},
#  {'day': 0, 'duration': 111, 'hour': 17},
#  {'day': 0, 'duration': 110, 'hour': 17},
#  {'day': 0, 'duration': 109, 'hour': 18},
#  {'day': 0, 'duration': 89, 'hour': 18},
#  {'day': 0, 'duration': 105, 'hour': 18},
#  {'day': 0, 'duration': 104, 'hour': 18},
#  {'day': 0, 'duration': 88, 'hour': 18},
#  {'day': 0, 'duration': 93, 'hour': 19},
#  {'day': 0, 'duration': 95, 'hour': 19},
#  {'day': 0, 'duration': 93, 'hour': 19},
#  {'day': 0, 'duration': 100, 'hour': 20},
#  {'day': 0, 'duration': 99, 'hour': 20},
#  {'day': 0, 'duration': 98, 'hour': 20},
#  {'day': 0, 'duration': 101, 'hour': 20},
#  {'day': 0, 'duration': 94, 'hour': 21},
#  {'day': 0, 'duration': 95, 'hour': 21},
#  {'day': 0, 'duration': 87, 'hour': 21},
#  {'day': 0, 'duration': 77, 'hour': 22},
#  {'day': 0, 'duration': 82, 'hour': 22},
#  {'day': 0, 'duration': 84, 'hour': 23},
#  {'day': 1, 'duration': 96, 'hour': 6},
#  {'day': 1, 'duration': 100, 'hour': 6},
#  {'day': 1, 'duration': 106, 'hour': 6},
#  {'day': 1, 'duration': 93, 'hour': 6},
#  {'day': 1, 'duration': 96, 'hour': 6},
#  {'day': 1, 'duration': 100, 'hour': 6},
#  {'day': 1, 'duration': 105, 'hour': 6},
#  {'day': 1, 'duration': 105, 'hour': 7},
#  {'day': 1, 'duration': 104, 'hour': 7},
#  {'day': 1, 'duration': 110, 'hour': 7},
#  {'day': 1, 'duration': 111, 'hour': 7},
#  {'day': 1, 'duration': 117, 'hour': 7},
#  {'day': 1, 'duration': 114, 'hour': 7},
#  {'day': 1, 'duration': 105, 'hour': 8},
#  {'day': 1, 'duration': 110, 'hour': 8},
#  {'day': 1, 'duration': 109, 'hour': 8},
#  {'day': 1, 'duration': 108, 'hour': 8},
#  {'day': 1, 'duration': 103, 'hour': 9},
#  {'day': 1, 'duration': 106, 'hour': 9},
#  {'day': 1, 'duration': 103, 'hour': 9},
#  {'day': 1, 'duration': 103, 'hour': 9},
#  {'day': 1, 'duration': 103, 'hour': 9},
#  {'day': 1, 'duration': 111, 'hour': 9},
#  {'day': 1, 'duration': 103, 'hour': 9},
#  {'day': 1, 'duration': 97, 'hour': 10},
#  {'day': 1, 'duration': 97, 'hour': 10},
#  {'day': 1, 'duration': 105, 'hour': 10},
#  {'day': 1, 'duration': 97, 'hour': 10},
#  {'day': 1, 'duration': 97, 'hour': 10},
#  {'day': 1, 'duration': 99, 'hour': 10},
#  {'day': 1, 'duration': 94, 'hour': 11},
#  {'day': 1, 'duration': 97, 'hour': 11},
#  {'day': 1, 'duration': 101, 'hour': 11},
#  {'day': 1, 'duration': 92, 'hour': 11},
#  {'day': 1, 'duration': 100, 'hour': 11},
#  {'day': 1, 'duration': 94, 'hour': 12},
#  {'day': 1, 'duration': 102, 'hour': 12},
#  {'day': 1, 'duration': 95, 'hour': 12},
#  {'day': 1, 'duration': 94, 'hour': 12},
#  {'day': 1, 'duration': 94, 'hour': 12},
#  {'day': 1, 'duration': 99, 'hour': 12},
#  {'day': 1, 'duration': 95, 'hour': 13},
#  {'day': 1, 'duration': 95, 'hour': 13},
#  {'day': 1, 'duration': 96, 'hour': 13},
#  {'day': 1, 'duration': 100, 'hour': 13},
#  {'day': 1, 'duration': 95, 'hour': 13},
#  {'day': 1, 'duration': 95, 'hour': 13},
#  {'day': 1, 'duration': 96, 'hour': 14},
#  {'day': 1, 'duration': 94, 'hour': 14},
#  {'day': 1, 'duration': 94, 'hour': 14},
#  {'day': 1, 'duration': 94, 'hour': 14},
#  {'day': 1, 'duration': 101, 'hour': 14},
#  {'day': 1, 'duration': 104, 'hour': 15},
#  {'day': 1, 'duration': 110, 'hour': 15},
#  {'day': 1, 'duration': 109, 'hour': 15},
#  {'day': 1, 'duration': 110, 'hour': 15},
#  {'day': 1, 'duration': 105, 'hour': 15},
#  {'day': 1, 'duration': 108, 'hour': 16},
#  {'day': 1, 'duration': 104, 'hour': 16},
#  {'day': 1, 'duration': 104, 'hour': 16},
#  {'day': 1, 'duration': 106, 'hour': 16},
#  {'day': 1, 'duration': 105, 'hour': 16},
#  {'day': 1, 'duration': 111, 'hour': 16},
#  {'day': 1, 'duration': 105, 'hour': 16},
#  {'day': 1, 'duration': 105, 'hour': 17},
#  {'day': 1, 'duration': 117, 'hour': 17},
#  {'day': 1, 'duration': 104, 'hour': 17},
#  {'day': 1, 'duration': 136, 'hour': 17},
#  {'day': 1, 'duration': 104, 'hour': 17},
#  {'day': 1, 'duration': 103, 'hour': 18},
#  {'day': 1, 'duration': 103, 'hour': 18},
#  {'day': 1, 'duration': 103, 'hour': 18},
#  {'day': 1, 'duration': 104, 'hour': 18},
#  {'day': 1, 'duration': 105, 'hour': 18},
#  {'day': 1, 'duration': 102, 'hour': 19},
#  {'day': 1, 'duration': 91, 'hour': 19},
#  {'day': 1, 'duration': 102, 'hour': 19},
#  {'day': 1, 'duration': 96, 'hour': 19},
#  {'day': 1, 'duration': 98, 'hour': 20},
#  {'day': 1, 'duration': 98, 'hour': 20},
#  {'day': 1, 'duration': 107, 'hour': 20},
#  {'day': 1, 'duration': 94, 'hour': 21},
#  {'day': 1, 'duration': 97, 'hour': 21},
#  {'day': 1, 'duration': 82, 'hour': 21},
#  {'day': 1, 'duration': 75, 'hour': 22},
#  {'day': 1, 'duration': 71, 'hour': 22},
#  {'day': 1, 'duration': 87, 'hour': 22},
#  {'day': 2, 'duration': 99, 'hour': 6},
#  {'day': 2, 'duration': 97, 'hour': 6},
#  {'day': 2, 'duration': 106, 'hour': 6},
#  {'day': 2, 'duration': 89, 'hour': 6},
#  {'day': 2, 'duration': 104, 'hour': 6},
#  {'day': 2, 'duration': 100, 'hour': 6},
#  {'day': 2, 'duration': 105, 'hour': 6},
#  {'day': 2, 'duration': 110, 'hour': 7},
#  {'day': 2, 'duration': 104, 'hour': 7},
#  {'day': 2, 'duration': 110, 'hour': 7},
#  {'day': 2, 'duration': 103, 'hour': 7},
#  {'day': 2, 'duration': 111, 'hour': 7},
#  {'day': 2, 'duration': 114, 'hour': 7},
#  {'day': 2, 'duration': 114, 'hour': 8},
#  {'day': 2, 'duration': 112, 'hour': 8},
#  {'day': 2, 'duration': 113, 'hour': 8},
#  {'day': 2, 'duration': 109, 'hour': 8},
#  {'day': 2, 'duration': 105, 'hour': 8},
#  {'day': 2, 'duration': 112, 'hour': 9},
#  {'day': 2, 'duration': 92, 'hour': 9},
#  {'day': 2, 'duration': 103, 'hour': 9},
#  {'day': 2, 'duration': 107, 'hour': 9},
#  {'day': 2, 'duration': 109, 'hour': 9},
#  {'day': 2, 'duration': 78, 'hour': 9},
#  {'day': 2, 'duration': 95, 'hour': 9},
#  {'day': 2, 'duration': 94, 'hour': 10},
#  {'day': 2, 'duration': 93, 'hour': 10},
#  {'day': 2, 'duration': 106, 'hour': 10},
#  {'day': 2, 'duration': 100, 'hour': 10},
#  {'day': 2, 'duration': 102, 'hour': 10},
#  {'day': 2, 'duration': 96, 'hour': 10},
#  {'day': 2, 'duration': 97, 'hour': 11},
#  {'day': 2, 'duration': 95, 'hour': 11},
#  {'day': 2, 'duration': 97, 'hour': 11},
#  {'day': 2, 'duration': 94, 'hour': 11},
#  {'day': 2, 'duration': 100, 'hour': 11},
#  {'day': 2, 'duration': 101, 'hour': 11},
#  {'day': 2, 'duration': 94, 'hour': 12},
#  {'day': 2, 'duration': 102, 'hour': 12},
#  {'day': 2, 'duration': 102, 'hour': 12},
#  {'day': 2, 'duration': 93, 'hour': 12},
#  {'day': 2, 'duration': 104, 'hour': 12},
#  {'day': 2, 'duration': 30, 'hour': 13},
#  {'day': 2, 'duration': 97, 'hour': 13},
#  {'day': 2, 'duration': 96, 'hour': 13},
#  {'day': 2, 'duration': 93, 'hour': 13},
#  {'day': 2, 'duration': 95, 'hour': 13},
#  {'day': 2, 'duration': 95, 'hour': 13},
#  {'day': 2, 'duration': 95, 'hour': 13},
#  {'day': 2, 'duration': 100, 'hour': 14},
#  {'day': 2, 'duration': 94, 'hour': 14},
#  {'day': 2, 'duration': 99, 'hour': 14},
#  {'day': 2, 'duration': 98, 'hour': 14},
#  {'day': 2, 'duration': 93, 'hour': 14},
#  {'day': 2, 'duration': 103, 'hour': 15},
#  {'day': 2, 'duration': 105, 'hour': 15},
#  {'day': 2, 'duration': 106, 'hour': 15},
#  {'day': 2, 'duration': 104, 'hour': 15},
#  {'day': 2, 'duration': 106, 'hour': 15},
#  {'day': 2, 'duration': 102, 'hour': 15},
#  {'day': 2, 'duration': 106, 'hour': 15},
#  {'day': 2, 'duration': 102, 'hour': 16},
#  {'day': 2, 'duration': 105, 'hour': 16},
#  {'day': 2, 'duration': 102, 'hour': 16},
#  {'day': 2, 'duration': 104, 'hour': 16},
#  {'day': 2, 'duration': 105, 'hour': 16},
#  {'day': 2, 'duration': 112, 'hour': 16},
#  {'day': 2, 'duration': 107, 'hour': 17},
#  {'day': 2, 'duration': 131, 'hour': 17},
#  {'day': 2, 'duration': 143, 'hour': 17},
#  {'day': 2, 'duration': 143, 'hour': 17},
#  {'day': 2, 'duration': 162, 'hour': 17},
#  {'day': 2, 'duration': 116, 'hour': 18},
#  {'day': 2, 'duration': 115, 'hour': 18},
#  {'day': 2, 'duration': 107, 'hour': 18},
#  {'day': 2, 'duration': 99, 'hour': 18},
#  {'day': 2, 'duration': 103, 'hour': 18},
#  {'day': 2, 'duration': 101, 'hour': 18},
#  {'day': 2, 'duration': 93, 'hour': 19},
#  {'day': 2, 'duration': 94, 'hour': 19},
#  {'day': 2, 'duration': 92, 'hour': 19},
#  {'day': 2, 'duration': 99, 'hour': 19},
#  {'day': 2, 'duration': 99, 'hour': 20},
#  {'day': 2, 'duration': 104, 'hour': 20},
#  {'day': 2, 'duration': 102, 'hour': 20},
#  {'day': 2, 'duration': 75, 'hour': 21},
#  {'day': 2, 'duration': 93, 'hour': 21},
#  {'day': 2, 'duration': 93, 'hour': 21},
#  {'day': 2, 'duration': 84, 'hour': 22},
#  {'day': 2, 'duration': 89, 'hour': 22},
#  {'day': 2, 'duration': 90, 'hour': 23},
#  {'day': 3, 'duration': 98, 'hour': 6},
#  {'day': 3, 'duration': 109, 'hour': 6},
#  {'day': 3, 'duration': 108, 'hour': 6},
#  {'day': 3, 'duration': 90, 'hour': 6},
#  {'day': 3, 'duration': 89, 'hour': 6},
#  {'day': 3, 'duration': 99, 'hour': 6},
#  {'day': 3, 'duration': 106, 'hour': 6},
#  {'day': 3, 'duration': 107, 'hour': 7},
#  {'day': 3, 'duration': 102, 'hour': 7},
#  {'day': 3, 'duration': 104, 'hour': 7},
#  {'day': 3, 'duration': 108, 'hour': 7},
#  {'day': 3, 'duration': 118, 'hour': 7},
#  {'day': 3, 'duration': 113, 'hour': 7},
#  {'day': 3, 'duration': 111, 'hour': 8},
#  {'day': 3, 'duration': 108, 'hour': 8},
#  {'day': 3, 'duration': 114, 'hour': 8},
#  {'day': 3, 'duration': 108, 'hour': 8},
#  {'day': 3, 'duration': 108, 'hour': 8},
#  {'day': 3, 'duration': 106, 'hour': 8},
#  {'day': 3, 'duration': 103, 'hour': 9},
#  {'day': 3, 'duration': 103, 'hour': 9},
#  {'day': 3, 'duration': 102, 'hour': 9},
#  {'day': 3, 'duration': 103, 'hour': 9},
#  {'day': 3, 'duration': 102, 'hour': 9},
#  {'day': 3, 'duration': 100, 'hour': 9},
#  {'day': 3, 'duration': 104, 'hour': 10},
#  {'day': 3, 'duration': 99, 'hour': 10},
#  {'day': 3, 'duration': 103, 'hour': 10},
#  {'day': 3, 'duration': 98, 'hour': 10},
#  {'day': 3, 'duration': 99, 'hour': 10},
#  {'day': 3, 'duration': 97, 'hour': 10},
#  {'day': 3, 'duration': 101, 'hour': 11},
#  {'day': 3, 'duration': 101, 'hour': 11},
#  {'day': 3, 'duration': 97, 'hour': 11},
#  {'day': 3, 'duration': 95, 'hour': 11},
#  {'day': 3, 'duration': 97, 'hour': 11},
#  {'day': 3, 'duration': 101, 'hour': 11},
#  {'day': 3, 'duration': 93, 'hour': 12},
#  {'day': 3, 'duration': 95, 'hour': 12},
#  {'day': 3, 'duration': 95, 'hour': 12},
#  {'day': 3, 'duration': 91, 'hour': 12},
#  {'day': 3, 'duration': 98, 'hour': 12},
#  {'day': 3, 'duration': 94, 'hour': 12},
#  {'day': 3, 'duration': 96, 'hour': 13},
#  {'day': 3, 'duration': 95, 'hour': 13},
#  {'day': 3, 'duration': 93, 'hour': 13},
#  {'day': 3, 'duration': 100, 'hour': 13},
#  {'day': 3, 'duration': 95, 'hour': 13},
#  {'day': 3, 'duration': 95, 'hour': 13},
#  {'day': 3, 'duration': 92, 'hour': 14},
#  {'day': 3, 'duration': 95, 'hour': 14},
#  {'day': 3, 'duration': 96, 'hour': 14},
#  {'day': 3, 'duration': 93, 'hour': 14},
#  {'day': 3, 'duration': 101, 'hour': 14},
#  {'day': 3, 'duration': 103, 'hour': 15},
#  {'day': 3, 'duration': 105, 'hour': 15},
#  {'day': 3, 'duration': 103, 'hour': 15},
#  {'day': 3, 'duration': 106, 'hour': 15},
#  {'day': 3, 'duration': 108, 'hour': 15},
#  {'day': 3, 'duration': 106, 'hour': 15},
#  {'day': 3, 'duration': 105, 'hour': 15},
#  {'day': 3, 'duration': 108, 'hour': 16},
#  {'day': 3, 'duration': 105, 'hour': 16},
#  {'day': 3, 'duration': 115, 'hour': 16},
#  {'day': 3, 'duration': 104, 'hour': 16},
#  {'day': 3, 'duration': 105, 'hour': 16},
#  {'day': 3, 'duration': 105, 'hour': 16},
#  {'day': 3, 'duration': 110, 'hour': 17},
#  {'day': 3, 'duration': 122, 'hour': 17},
#  {'day': 3, 'duration': 103, 'hour': 17},
#  {'day': 3, 'duration': 109, 'hour': 17},
#  {'day': 3, 'duration': 105, 'hour': 17},
#  {'day': 3, 'duration': 107, 'hour': 18},
#  {'day': 3, 'duration': 108, 'hour': 18},
#  {'day': 3, 'duration': 110, 'hour': 18},
#  {'day': 3, 'duration': 103, 'hour': 18},
#  {'day': 3, 'duration': 104, 'hour': 18},
#  {'day': 3, 'duration': 112, 'hour': 18},
#  {'day': 3, 'duration': 93, 'hour': 19},
#  {'day': 3, 'duration': 96, 'hour': 19},
#  {'day': 3, 'duration': 96, 'hour': 19},
#  {'day': 3, 'duration': 96, 'hour': 19},
#  {'day': 3, 'duration': 93, 'hour': 20},
#  {'day': 3, 'duration': 99, 'hour': 20},
#  {'day': 3, 'duration': 104, 'hour': 20},
#  {'day': 3, 'duration': 94, 'hour': 21},
#  {'day': 3, 'duration': 93, 'hour': 21},
#  {'day': 3, 'duration': 94, 'hour': 21},
#  {'day': 3, 'duration': 74, 'hour': 22},
#  {'day': 3, 'duration': 90, 'hour': 22},
#  {'day': 4, 'duration': 95, 'hour': 6},
#  {'day': 4, 'duration': 92, 'hour': 6},
#  {'day': 4, 'duration': 93, 'hour': 6},
#  {'day': 4, 'duration': 93, 'hour': 6},
#  {'day': 4, 'duration': 91, 'hour': 6},
#  {'day': 4, 'duration': 100, 'hour': 6},
#  {'day': 4, 'duration': 104, 'hour': 6},
#  {'day': 4, 'duration': 106, 'hour': 7},
#  {'day': 4, 'duration': 102, 'hour': 7},
#  {'day': 4, 'duration': 107, 'hour': 7},
#  {'day': 4, 'duration': 107, 'hour': 7},
#  {'day': 4, 'duration': 118, 'hour': 7},
#  {'day': 4, 'duration': 110, 'hour': 7},
#  {'day': 4, 'duration': 111, 'hour': 8},
#  {'day': 4, 'duration': 107, 'hour': 8},
#  {'day': 4, 'duration': 107, 'hour': 8},
#  {'day': 4, 'duration': 109, 'hour': 8},
#  {'day': 4, 'duration': 110, 'hour': 8},
#  {'day': 4, 'duration': 104, 'hour': 9},
#  {'day': 4, 'duration': 106, 'hour': 9},
#  {'day': 4, 'duration': 109, 'hour': 9},
#  {'day': 4, 'duration': 137, 'hour': 9},
#  {'day': 4, 'duration': 104, 'hour': 9},
#  {'day': 4, 'duration': 103, 'hour': 9},
#  {'day': 4, 'duration': 92, 'hour': 10},
#  {'day': 4, 'duration': 100, 'hour': 10},
#  {'day': 4, 'duration': 99, 'hour': 10},
#  {'day': 4, 'duration': 103, 'hour': 10},
#  {'day': 4, 'duration': 102, 'hour': 10},
#  {'day': 4, 'duration': 97, 'hour': 10},
#  {'day': 4, 'duration': 101, 'hour': 10},
#  {'day': 4, 'duration': 98, 'hour': 11},
#  {'day': 4, 'duration': 99, 'hour': 11},
#  {'day': 4, 'duration': 98, 'hour': 11},
#  {'day': 4, 'duration': 75, 'hour': 11},
#  {'day': 4, 'duration': 96, 'hour': 11},
#  {'day': 4, 'duration': 100, 'hour': 11},
#  {'day': 4, 'duration': 79, 'hour': 12},
#  {'day': 4, 'duration': 93, 'hour': 12},
#  {'day': 4, 'duration': 96, 'hour': 12},
#  {'day': 4, 'duration': 103, 'hour': 12},
#  {'day': 4, 'duration': 90, 'hour': 12},
#  {'day': 4, 'duration': 94, 'hour': 12},
#  {'day': 4, 'duration': 96, 'hour': 12},
#  {'day': 4, 'duration': 98, 'hour': 13},
#  {'day': 4, 'duration': 96, 'hour': 13},
#  {'day': 4, 'duration': 93, 'hour': 13},
#  {'day': 4, 'duration': 99, 'hour': 13},
#  {'day': 4, 'duration': 100, 'hour': 13},
#  {'day': 4, 'duration': 95, 'hour': 13},
#  {'day': 4, 'duration': 98, 'hour': 14},
#  {'day': 4, 'duration': 93, 'hour': 14},
#  {'day': 4, 'duration': 95, 'hour': 14},
#  {'day': 4, 'duration': 94, 'hour': 14},
#  {'day': 4, 'duration': 93, 'hour': 14},
#  {'day': 4, 'duration': 102, 'hour': 15},
#  {'day': 4, 'duration': 105, 'hour': 15},
#  {'day': 4, 'duration': 110, 'hour': 15},
#  {'day': 4, 'duration': 102, 'hour': 15},
#  {'day': 4, 'duration': 103, 'hour': 15},
#  {'day': 4, 'duration': 110, 'hour': 15},
#  {'day': 4, 'duration': 110, 'hour': 16},
#  {'day': 4, 'duration': 109, 'hour': 16},
#  {'day': 4, 'duration': 109, 'hour': 16},
#  {'day': 4, 'duration': 102, 'hour': 16},
#  {'day': 4, 'duration': 108, 'hour': 16},
#  {'day': 4, 'duration': 105, 'hour': 16},
#  {'day': 4, 'duration': 105, 'hour': 16},
#  {'day': 4, 'duration': 111, 'hour': 17},
#  {'day': 4, 'duration': 119, 'hour': 17},
#  {'day': 4, 'duration': 108, 'hour': 17},
#  {'day': 4, 'duration': 107, 'hour': 17},
#  {'day': 4, 'duration': 104, 'hour': 17},
#  {'day': 4, 'duration': 112, 'hour': 17},
#  {'day': 4, 'duration': 106, 'hour': 18},
#  {'day': 4, 'duration': 106, 'hour': 18},
#  {'day': 4, 'duration': 104, 'hour': 18},
#  {'day': 4, 'duration': 101, 'hour': 18},
#  {'day': 4, 'duration': 120, 'hour': 18},
#  {'day': 4, 'duration': 91, 'hour': 19},
#  {'day': 4, 'duration': 99, 'hour': 19},
#  {'day': 4, 'duration': 96, 'hour': 19},
#  {'day': 4, 'duration': 84, 'hour': 19},
#  {'day': 4, 'duration': 97, 'hour': 20},
#  {'day': 4, 'duration': 81, 'hour': 20},
#  {'day': 4, 'duration': 100, 'hour': 20},
#  {'day': 4, 'duration': 94, 'hour': 21},
#  {'day': 4, 'duration': 93, 'hour': 21},
#  {'day': 4, 'duration': 94, 'hour': 21},
#  {'day': 4, 'duration': 93, 'hour': 22},
#  {'day': 4, 'duration': 101, 'hour': 22},
#  {'day': 4, 'duration': 105, 'hour': 23},
#  {'day': 5, 'duration': 106, 'hour': 6},
#  {'day': 5, 'duration': 101, 'hour': 6},
#  {'day': 5, 'duration': 96, 'hour': 7},
#  {'day': 5, 'duration': 90, 'hour': 7},
#  {'day': 5, 'duration': 102, 'hour': 7},
#  {'day': 5, 'duration': 104, 'hour': 7},
#  {'day': 5, 'duration': 100, 'hour': 7},
#  {'day': 5, 'duration': 110, 'hour': 8},
#  {'day': 5, 'duration': 102, 'hour': 8},
#  {'day': 5, 'duration': 109, 'hour': 8},
#  {'day': 5, 'duration': 105, 'hour': 9},
#  {'day': 5, 'duration': 107, 'hour': 9},
#  {'day': 5, 'duration': 105, 'hour': 9},
#  {'day': 5, 'duration': 103, 'hour': 9},
#  {'day': 5, 'duration': 103, 'hour': 9},
#  {'day': 5, 'duration': 104, 'hour': 10},
#  {'day': 5, 'duration': 158, 'hour': 10},
#  {'day': 5, 'duration': 104, 'hour': 10},
#  {'day': 5, 'duration': 97, 'hour': 11},
#  {'day': 5, 'duration': 104, 'hour': 11},
#  {'day': 5, 'duration': 109, 'hour': 11},
#  {'day': 5, 'duration': 105, 'hour': 11},
#  {'day': 5, 'duration': 102, 'hour': 11},
#  {'day': 5, 'duration': 99, 'hour': 12},
#  {'day': 5, 'duration': 108, 'hour': 12},
#  {'day': 5, 'duration': 99, 'hour': 12},
#  {'day': 5, 'duration': 103, 'hour': 12},
#  {'day': 5, 'duration': 107, 'hour': 13},
#  {'day': 5, 'duration': 101, 'hour': 13},
#  {'day': 5, 'duration': 102, 'hour': 13},
#  {'day': 5, 'duration': 102, 'hour': 13},
#  {'day': 5, 'duration': 37, 'hour': 14},
#  {'day': 5, 'duration': 101, 'hour': 14},
#  {'day': 5, 'duration': 98, 'hour': 14},
#  {'day': 5, 'duration': 98, 'hour': 15},
#  {'day': 5, 'duration': 100, 'hour': 15},
#  {'day': 5, 'duration': 101, 'hour': 15},
#  {'day': 5, 'duration': 101, 'hour': 15},
#  {'day': 5, 'duration': 133, 'hour': 16},
#  {'day': 5, 'duration': 117, 'hour': 16},
#  {'day': 5, 'duration': 143, 'hour': 16},
#  {'day': 5, 'duration': 89, 'hour': 16},
#  {'day': 5, 'duration': 98, 'hour': 16},
#  {'day': 5, 'duration': 98, 'hour': 17},
#  {'day': 5, 'duration': 108, 'hour': 17},
#  {'day': 5, 'duration': 74, 'hour': 18},
#  {'day': 5, 'duration': 88, 'hour': 18},
#  {'day': 5, 'duration': 93, 'hour': 18},
#  {'day': 5, 'duration': 101, 'hour': 18},
#  {'day': 5, 'duration': 92, 'hour': 19},
#  {'day': 5, 'duration': 101, 'hour': 19},
#  {'day': 5, 'duration': 93, 'hour': 19},
#  {'day': 5, 'duration': 95, 'hour': 19},
#  {'day': 5, 'duration': 95, 'hour': 20},
#  {'day': 5, 'duration': 96, 'hour': 20},
#  {'day': 5, 'duration': 95, 'hour': 20},
#  {'day': 5, 'duration': 97, 'hour': 21},
#  {'day': 5, 'duration': 94, 'hour': 21},
#  {'day': 5, 'duration': 91, 'hour': 21},
#  {'day': 5, 'duration': 83, 'hour': 22},
#  {'day': 5, 'duration': 94, 'hour': 22},
#  {'day': 5, 'duration': 99, 'hour': 22},
#  {'day': 6, 'duration': 77, 'hour': 9},
#  {'day': 6, 'duration': 74, 'hour': 9},
#  {'day': 6, 'duration': 74, 'hour': 9},
#  {'day': 6, 'duration': 84, 'hour': 9},
#  {'day': 6, 'duration': 72, 'hour': 10},
#  {'day': 6, 'duration': 79, 'hour': 10},
#  {'day': 6, 'duration': 93, 'hour': 11},
#  {'day': 6, 'duration': 90, 'hour': 11},
#  {'day': 6, 'duration': 99, 'hour': 11},
#  {'day': 6, 'duration': 95, 'hour': 11},
#  {'day': 6, 'duration': 96, 'hour': 12},
#  {'day': 6, 'duration': 96, 'hour': 12},
#  {'day': 6, 'duration': 111, 'hour': 13},
#  {'day': 6, 'duration': 92, 'hour': 13},
#  {'day': 6, 'duration': 100, 'hour': 13},
#  {'day': 6, 'duration': 100, 'hour': 14},
#  {'day': 6, 'duration': 103, 'hour': 14},
#  {'day': 6, 'duration': 109, 'hour': 14},
#  {'day': 6, 'duration': 94, 'hour': 15},
#  {'day': 6, 'duration': 96, 'hour': 15},
#  {'day': 6, 'duration': 105, 'hour': 15},
#  {'day': 6, 'duration': 102, 'hour': 15},
#  {'day': 6, 'duration': 97, 'hour': 16},
#  {'day': 6, 'duration': 98, 'hour': 16},
#  {'day': 6, 'duration': 90, 'hour': 17},
#  {'day': 6, 'duration': 181, 'hour': 17},
#  {'day': 6, 'duration': 124, 'hour': 17},
#  {'day': 6, 'duration': 88, 'hour': 18},
#  {'day': 6, 'duration': 97, 'hour': 18},
#  {'day': 6, 'duration': 93, 'hour': 18},
#  {'day': 6, 'duration': 82, 'hour': 19},
#  {'day': 6, 'duration': 112, 'hour': 19},
#  {'day': 6, 'duration': 93, 'hour': 19},
#  {'day': 6, 'duration': 87, 'hour': 20},
#  {'day': 6, 'duration': 87, 'hour': 20},
#  {'day': 6, 'duration': 75, 'hour': 21},
#  {'day': 6, 'duration': 81, 'hour': 21},
#  {'day': 6, 'duration': 76, 'hour': 22},
#  {'day': 6, 'duration': 86, 'hour': 22},
#  {'day': 0, 'duration': 97, 'hour': 6},
#  {'day': 0, 'duration': 88, 'hour': 6},
#  {'day': 0, 'duration': 92, 'hour': 6},
#  {'day': 0, 'duration': 100, 'hour': 6},
#  {'day': 0, 'duration': 96, 'hour': 6},
#  {'day': 0, 'duration': 100, 'hour': 6},
#  {'day': 0, 'duration': 104, 'hour': 6},
#  {'day': 0, 'duration': 96, 'hour': 7},
#  {'day': 0, 'duration': 104, 'hour': 7},
#  {'day': 0, 'duration': 112, 'hour': 7},
#  {'day': 0, 'duration': 110, 'hour': 7},
#  {'day': 0, 'duration': 107, 'hour': 7},
#  {'day': 0, 'duration': 114, 'hour': 7},
#  {'day': 0, 'duration': 111, 'hour': 8},
#  {'day': 0, 'duration': 108, 'hour': 8},
#  {'day': 0, 'duration': 107, 'hour': 8},
#  {'day': 0, 'duration': 113, 'hour': 8},
#  {'day': 0, 'duration': 107, 'hour': 8},
#  {'day': 0, 'duration': 102, 'hour': 9},
#  {'day': 0, 'duration': 101, 'hour': 9},
#  {'day': 0, 'duration': 102, 'hour': 9},
#  {'day': 0, 'duration': 113, 'hour': 9},
#  {'day': 0, 'duration': 106, 'hour': 9},
#  {'day': 0, 'duration': 100, 'hour': 9},
#  {'day': 0, 'duration': 97, 'hour': 9},
#  {'day': 0, 'duration': 102, 'hour': 10},
#  {'day': 0, 'duration': 97, 'hour': 10},
#  {'day': 0, 'duration': 103, 'hour': 10},
#  {'day': 0, 'duration': 97, 'hour': 10},
#  {'day': 0, 'duration': 96, 'hour': 10},
#  {'day': 0, 'duration': 102, 'hour': 10},
#  {'day': 0, 'duration': 96, 'hour': 11},
#  {'day': 0, 'duration': 95, 'hour': 11},
#  {'day': 0, 'duration': 99, 'hour': 11},
#  {'day': 0, 'duration': 95, 'hour': 11},
#  {'day': 0, 'duration': 97, 'hour': 11},
#  {'day': 0, 'duration': 91, 'hour': 12},
#  {'day': 0, 'duration': 102, 'hour': 12},
#  {'day': 0, 'duration': 74, 'hour': 12},
#  {'day': 0, 'duration': 109, 'hour': 12},
#  {'day': 0, 'duration': 95, 'hour': 12},
#  {'day': 0, 'duration': 82, 'hour': 12},
#  {'day': 0, 'duration': 95, 'hour': 12},
#  {'day': 0, 'duration': 101, 'hour': 13},
#  {'day': 0, 'duration': 94, 'hour': 13},
#  {'day': 0, 'duration': 95, 'hour': 13},
#  {'day': 0, 'duration': 94, 'hour': 13},
#  {'day': 0, 'duration': 95, 'hour': 13},
#  {'day': 0, 'duration': 95, 'hour': 13},
#  {'day': 0, 'duration': 94, 'hour': 14},
#  {'day': 0, 'duration': 95, 'hour': 14},
#  {'day': 0, 'duration': 93, 'hour': 14},
#  {'day': 0, 'duration': 93, 'hour': 14},
#  {'day': 0, 'duration': 100, 'hour': 14},
#  {'day': 0, 'duration': 102, 'hour': 15},
#  {'day': 0, 'duration': 103, 'hour': 15},
#  {'day': 0, 'duration': 131, 'hour': 15},
#  {'day': 0, 'duration': 110, 'hour': 15},
#  {'day': 0, 'duration': 105, 'hour': 15},
#  {'day': 0, 'duration': 105, 'hour': 15},
#  {'day': 0, 'duration': 106, 'hour': 15},
#  {'day': 0, 'duration': 105, 'hour': 16},
#  {'day': 0, 'duration': 102, 'hour': 16},
#  {'day': 0, 'duration': 110, 'hour': 16},
#  {'day': 0, 'duration': 109, 'hour': 16},
#  {'day': 0, 'duration': 106, 'hour': 16},
#  {'day': 0, 'duration': 107, 'hour': 16},
#  {'day': 0, 'duration': 104, 'hour': 17},
#  {'day': 0, 'duration': 114, 'hour': 17},
#  {'day': 0, 'duration': 104, 'hour': 17},
#  {'day': 0, 'duration': 109, 'hour': 17},
#  {'day': 0, 'duration': 104, 'hour': 18},
#  {'day': 0, 'duration': 107, 'hour': 18},
#  {'day': 0, 'duration': 106, 'hour': 18},
#  {'day': 0, 'duration': 104, 'hour': 18},
#  {'day': 0, 'duration': 97, 'hour': 18},
#  {'day': 0, 'duration': 103, 'hour': 18},
#  {'day': 0, 'duration': 96, 'hour': 18},
#  {'day': 0, 'duration': 100, 'hour': 19},
#  {'day': 0, 'duration': 95, 'hour': 19},
#  {'day': 0, 'duration': 96, 'hour': 19},
#  {'day': 0, 'duration': 99, 'hour': 20},
#  {'day': 0, 'duration': 100, 'hour': 20},
#  {'day': 0, 'duration': 98, 'hour': 20},
#  {'day': 0, 'duration': 94, 'hour': 21},
#  {'day': 0, 'duration': 93, 'hour': 21},
#  {'day': 0, 'duration': 112, 'hour': 22},
#  {'day': 0, 'duration': 104, 'hour': 22},
#  {'day': 0, 'duration': 79, 'hour': 22},
#  {'day': 0, 'duration': 79, 'hour': 23},
#  {'day': 1, 'duration': 102, 'hour': 6},
#  {'day': 1, 'duration': 99, 'hour': 6},
#  {'day': 1, 'duration': 96, 'hour': 6},
#  {'day': 1, 'duration': 94, 'hour': 6},
#  {'day': 1, 'duration': 94, 'hour': 6},
#  {'day': 1, 'duration': 98, 'hour': 6},
#  {'day': 1, 'duration': 105, 'hour': 6},
#  {'day': 1, 'duration': 103, 'hour': 7},
#  {'day': 1, 'duration': 103, 'hour': 7},
#  {'day': 1, 'duration': 101, 'hour': 7},
#  {'day': 1, 'duration': 103, 'hour': 7},
#  {'day': 1, 'duration': 108, 'hour': 7},
#  {'day': 1, 'duration': 104, 'hour': 7},
#  {'day': 1, 'duration': 111, 'hour': 8},
#  {'day': 1, 'duration': 109, 'hour': 8},
#  {'day': 1, 'duration': 107, 'hour': 8},
#  {'day': 1, 'duration': 111, 'hour': 8},
#  {'day': 1, 'duration': 103, 'hour': 8},
#  {'day': 1, 'duration': 103, 'hour': 9},
#  {'day': 1, 'duration': 104, 'hour': 9},
#  {'day': 1, 'duration': 116, 'hour': 9},
#  {'day': 1, 'duration': 104, 'hour': 9},
#  {'day': 1, 'duration': 105, 'hour': 9},
#  {'day': 1, 'duration': 106, 'hour': 9},
#  {'day': 1, 'duration': 98, 'hour': 9},
#  {'day': 1, 'duration': 94, 'hour': 10},
#  {'day': 1, 'duration': 103, 'hour': 10},
#  {'day': 1, 'duration': 97, 'hour': 10},
#  {'day': 1, 'duration': 97, 'hour': 10},
#  {'day': 1, 'duration': 98, 'hour': 10},
#  {'day': 1, 'duration': 99, 'hour': 10},
#  {'day': 1, 'duration': 101, 'hour': 10},
#  {'day': 1, 'duration': 96, 'hour': 11},
#  {'day': 1, 'duration': 103, 'hour': 11},
#  {'day': 1, 'duration': 90, 'hour': 11},
#  {'day': 1, 'duration': 92, 'hour': 11},
#  {'day': 1, 'duration': 107, 'hour': 11},
#  {'day': 1, 'duration': 95, 'hour': 11},
#  {'day': 1, 'duration': 102, 'hour': 12},
#  {'day': 1, 'duration': 99, 'hour': 12},
#  {'day': 1, 'duration': 97, 'hour': 12},
#  {'day': 1, 'duration': 97, 'hour': 12},
#  {'day': 1, 'duration': 99, 'hour': 12},
#  {'day': 1, 'duration': 96, 'hour': 12},
#  {'day': 1, 'duration': 100, 'hour': 13},
#  {'day': 1, 'duration': 92, 'hour': 13},
#  {'day': 1, 'duration': 98, 'hour': 13},
#  {'day': 1, 'duration': 95, 'hour': 13},
#  {'day': 1, 'duration': 95, 'hour': 13},
#  {'day': 1, 'duration': 96, 'hour': 13},
#  {'day': 1, 'duration': 93, 'hour': 14},
#  {'day': 1, 'duration': 100, 'hour': 14},
#  {'day': 1, 'duration': 97, 'hour': 14},
#  {'day': 1, 'duration': 96, 'hour': 14},
#  {'day': 1, 'duration': 96, 'hour': 14},
# ...
#  {'day': 0, 'duration': 105, 'hour': 17},
#  {'day': 0, 'duration': 107, 'hour': 17},
#  {'day': 0, 'duration': 105, 'hour': 17},
#  {'day': 0, 'duration': 109, 'hour': 17},
#  {'day': 0, 'duration': 105, 'hour': 17},
#  {'day': 0, 'duration': 106, 'hour': 17},
#  {'day': 0, 'duration': 105, 'hour': 18},
#  {'day': 0, 'duration': 80, 'hour': 18},
#  {'day': 0, 'duration': 105, 'hour': 18},
#  {'day': 0, 'duration': 101, 'hour': 18},
#  {'day': 0, 'duration': 88, 'hour': 18},
#  {'day': 0, 'duration': 92, 'hour': 19},
#  {'day': 0, 'duration': 94, 'hour': 19},
#  {'day': 0, 'duration': 93, 'hour': 19},
#  {'day': 0, 'duration': 99, 'hour': 19},
#  {'day': 0, 'duration': 105, 'hour': 20},
#  {'day': 0, 'duration': 98, 'hour': 20},
#  {'day': 0, 'duration': 99, 'hour': 20},
#  {'day': 0, 'duration': 101, 'hour': 21},
#  {'day': 0, 'duration': 97, 'hour': 21},
#  {'day': 0, 'duration': 91, 'hour': 21},
#  {'day': 0, 'duration': 70, 'hour': 22},
#  {'day': 0, 'duration': 79, 'hour': 22},
#  {'day': 0, 'duration': 83, 'hour': 23},
#  {'day': 1, 'duration': 98, 'hour': 6},
#  {'day': 1, 'duration': 95, 'hour': 6},
#  {'day': 1, 'duration': 103, 'hour': 6},
#  {'day': 1, 'duration': 103, 'hour': 6},
#  {'day': 1, 'duration': 96, 'hour': 6},
#  {'day': 1, 'duration': 99, 'hour': 6},
#  {'day': 1, 'duration': 105, 'hour': 6},
#  {'day': 1, 'duration': 104, 'hour': 7},
#  {'day': 1, 'duration': 100, 'hour': 7},
#  {'day': 1, 'duration': 104, 'hour': 7},
#  {'day': 1, 'duration': 107, 'hour': 7},
#  {'day': 1, 'duration': 108, 'hour': 7},
#  {'day': 1, 'duration': 114, 'hour': 7},
#  {'day': 1, 'duration': 106, 'hour': 8},
#  {'day': 1, 'duration': 110, 'hour': 8},
#  {'day': 1, 'duration': 110, 'hour': 8},
#  {'day': 1, 'duration': 109, 'hour': 8},
#  {'day': 1, 'duration': 108, 'hour': 8},
#  {'day': 1, 'duration': 104, 'hour': 8},
#  {'day': 1, 'duration': 104, 'hour': 9},
#  {'day': 1, 'duration': 102, 'hour': 9},
#  {'day': 1, 'duration': 101, 'hour': 9},
#  {'day': 1, 'duration': 103, 'hour': 9},
#  {'day': 1, 'duration': 165, 'hour': 9},
#  {'day': 1, 'duration': 98, 'hour': 9},
#  {'day': 1, 'duration': 99, 'hour': 10},
#  {'day': 1, 'duration': 101, 'hour': 10},
#  {'day': 1, 'duration': 98, 'hour': 10},
#  {'day': 1, 'duration': 98, 'hour': 10},
#  {'day': 1, 'duration': 96, 'hour': 10},
#  {'day': 1, 'duration': 98, 'hour': 10},
#  {'day': 1, 'duration': 93, 'hour': 11},
#  {'day': 1, 'duration': 98, 'hour': 11},
#  {'day': 1, 'duration': 97, 'hour': 11},
#  {'day': 1, 'duration': 99, 'hour': 11},
#  {'day': 1, 'duration': 103, 'hour': 11},
#  {'day': 1, 'duration': 96, 'hour': 11},
#  {'day': 1, 'duration': 104, 'hour': 12},
#  {'day': 1, 'duration': 96, 'hour': 12},
#  {'day': 1, 'duration': 92, 'hour': 12},
#  {'day': 1, 'duration': 95, 'hour': 12},
#  {'day': 1, 'duration': 93, 'hour': 12},
#  {'day': 1, 'duration': 102, 'hour': 13},
#  {'day': 1, 'duration': 99, 'hour': 13},
#  {'day': 1, 'duration': 99, 'hour': 13},
#  {'day': 1, 'duration': 94, 'hour': 13},
#  {'day': 1, 'duration': 98, 'hour': 13},
#  {'day': 1, 'duration': 95, 'hour': 13},
#  {'day': 1, 'duration': 96, 'hour': 13},
#  {'day': 1, 'duration': 94, 'hour': 14},
#  {'day': 1, 'duration': 94, 'hour': 14},
#  {'day': 1, 'duration': 93, 'hour': 14},
#  {'day': 1, 'duration': 94, 'hour': 14},
#  {'day': 1, 'duration': 93, 'hour': 14},
#  {'day': 1, 'duration': 112, 'hour': 14},
#  {'day': 1, 'duration': 107, 'hour': 15},
#  {'day': 1, 'duration': 102, 'hour': 15},
#  {'day': 1, 'duration': 104, 'hour': 15},
#  {'day': 1, 'duration': 102, 'hour': 15},
#  {'day': 1, 'duration': 109, 'hour': 15},
#  {'day': 1, 'duration': 107, 'hour': 16},
#  {'day': 1, 'duration': 114, 'hour': 16},
#  {'day': 1, 'duration': 108, 'hour': 16},
#  {'day': 1, 'duration': 104, 'hour': 16},
#  {'day': 1, 'duration': 110, 'hour': 16},
#  {'day': 1, 'duration': 110, 'hour': 16},
#  {'day': 1, 'duration': 113, 'hour': 16},
#  {'day': 1, 'duration': 111, 'hour': 17},
#  {'day': 1, 'duration': 117, 'hour': 17},
#  {'day': 1, 'duration': 105, 'hour': 17},
#  {'day': 1, 'duration': 113, 'hour': 17},
#  {'day': 1, 'duration': 111, 'hour': 17},
#  {'day': 1, 'duration': 111, 'hour': 17},
#  {'day': 1, 'duration': 103, 'hour': 18},
#  {'day': 1, 'duration': 101, 'hour': 18},
#  {'day': 1, 'duration': 103, 'hour': 18},
#  {'day': 1, 'duration': 104, 'hour': 18},
#  {'day': 1, 'duration': 106, 'hour': 18},
#  {'day': 1, 'duration': 100, 'hour': 18},
#  {'day': 1, 'duration': 92, 'hour': 19},
#  {'day': 1, 'duration': 95, 'hour': 19},
#  {'day': 1, 'duration': 96, 'hour': 19},
#  {'day': 1, 'duration': 93, 'hour': 20},
#  {'day': 1, 'duration': 98, 'hour': 20},
#  {'day': 1, 'duration': 104, 'hour': 20},
#  {'day': 1, 'duration': 99, 'hour': 21},
#  {'day': 1, 'duration': 97, 'hour': 21},
#  {'day': 1, 'duration': 92, 'hour': 21},
#  {'day': 1, 'duration': 73, 'hour': 22},
#  {'day': 1, 'duration': 83, 'hour': 22},
#  {'day': 1, 'duration': 79, 'hour': 23},
#  {'day': 2, 'duration': 105, 'hour': 6},
#  {'day': 2, 'duration': 103, 'hour': 6},
#  {'day': 2, 'duration': 92, 'hour': 6},
#  {'day': 2, 'duration': 103, 'hour': 6},
#  {'day': 2, 'duration': 93, 'hour': 6},
#  {'day': 2, 'duration': 106, 'hour': 6},
#  {'day': 2, 'duration': 102, 'hour': 7},
#  {'day': 2, 'duration': 100, 'hour': 7},
#  {'day': 2, 'duration': 107, 'hour': 7},
#  {'day': 2, 'duration': 107, 'hour': 7},
#  {'day': 2, 'duration': 109, 'hour': 7},
#  {'day': 2, 'duration': 110, 'hour': 7},
#  {'day': 2, 'duration': 114, 'hour': 7},
#  {'day': 2, 'duration': 109, 'hour': 8},
#  {'day': 2, 'duration': 109, 'hour': 8},
#  {'day': 2, 'duration': 115, 'hour': 8},
#  {'day': 2, 'duration': 109, 'hour': 8},
#  {'day': 2, 'duration': 106, 'hour': 8},
#  {'day': 2, 'duration': 105, 'hour': 8},
#  {'day': 2, 'duration': 109, 'hour': 9},
#  {'day': 2, 'duration': 103, 'hour': 9},
#  {'day': 2, 'duration': 103, 'hour': 9},
#  {'day': 2, 'duration': 108, 'hour': 9},
#  {'day': 2, 'duration': 92, 'hour': 9},
#  {'day': 2, 'duration': 99, 'hour': 9},
#  {'day': 2, 'duration': 92, 'hour': 10},
#  {'day': 2, 'duration': 93, 'hour': 10},
#  {'day': 2, 'duration': 99, 'hour': 10},
#  {'day': 2, 'duration': 98, 'hour': 10},
#  {'day': 2, 'duration': 97, 'hour': 10},
#  {'day': 2, 'duration': 100, 'hour': 10},
#  {'day': 2, 'duration': 94, 'hour': 11},
#  {'day': 2, 'duration': 97, 'hour': 11},
#  {'day': 2, 'duration': 134, 'hour': 11},
#  {'day': 2, 'duration': 92, 'hour': 11},
#  {'day': 2, 'duration': 93, 'hour': 11},
#  {'day': 2, 'duration': 94, 'hour': 11},
#  {'day': 2, 'duration': 95, 'hour': 12},
#  {'day': 2, 'duration': 95, 'hour': 12},
#  {'day': 2, 'duration': 95, 'hour': 12},
#  {'day': 2, 'duration': 94, 'hour': 12},
#  {'day': 2, 'duration': 96, 'hour': 12},
#  {'day': 2, 'duration': 97, 'hour': 12},
#  {'day': 2, 'duration': 99, 'hour': 13},
#  {'day': 2, 'duration': 98, 'hour': 13},
#  {'day': 2, 'duration': 94, 'hour': 13},
#  {'day': 2, 'duration': 99, 'hour': 13},
#  {'day': 2, 'duration': 95, 'hour': 13},
#  {'day': 2, 'duration': 96, 'hour': 13},
#  {'day': 2, 'duration': 98, 'hour': 14},
#  {'day': 2, 'duration': 102, 'hour': 14},
#  {'day': 2, 'duration': 94, 'hour': 14},
#  {'day': 2, 'duration': 89, 'hour': 14},
#  {'day': 2, 'duration': 90, 'hour': 14},
#  {'day': 2, 'duration': 102, 'hour': 15},
#  {'day': 2, 'duration': 103, 'hour': 15},
#  {'day': 2, 'duration': 110, 'hour': 15},
#  {'day': 2, 'duration': 104, 'hour': 15},
#  {'day': 2, 'duration': 103, 'hour': 15},
#  {'day': 2, 'duration': 105, 'hour': 15},
#  {'day': 2, 'duration': 103, 'hour': 16},
#  {'day': 2, 'duration': 117, 'hour': 16},
#  {'day': 2, 'duration': 104, 'hour': 16},
#  {'day': 2, 'duration': 104, 'hour': 16},
#  {'day': 2, 'duration': 105, 'hour': 16},
#  {'day': 2, 'duration': 111, 'hour': 16},
#  {'day': 2, 'duration': 109, 'hour': 16},
#  {'day': 2, 'duration': 122, 'hour': 17},
#  {'day': 2, 'duration': 125, 'hour': 17},
#  {'day': 2, 'duration': 110, 'hour': 17},
#  {'day': 2, 'duration': 109, 'hour': 17},
#  {'day': 2, 'duration': 105, 'hour': 17},
#  {'day': 2, 'duration': 104, 'hour': 17},
#  {'day': 2, 'duration': 102, 'hour': 18},
#  {'day': 2, 'duration': 65, 'hour': 18},
#  {'day': 2, 'duration': 106, 'hour': 18},
#  {'day': 2, 'duration': 105, 'hour': 18},
#  {'day': 2, 'duration': 108, 'hour': 18},
#  {'day': 2, 'duration': 92, 'hour': 19},
#  {'day': 2, 'duration': 94, 'hour': 19},
#  {'day': 2, 'duration': 93, 'hour': 19},
#  {'day': 2, 'duration': 99, 'hour': 19},
#  {'day': 2, 'duration': 100, 'hour': 20},
#  {'day': 2, 'duration': 98, 'hour': 20},
#  {'day': 2, 'duration': 95, 'hour': 20},
#  {'day': 2, 'duration': 96, 'hour': 21},
#  {'day': 2, 'duration': 93, 'hour': 21},
#  {'day': 2, 'duration': 88, 'hour': 21},
#  {'day': 2, 'duration': 77, 'hour': 22},
#  {'day': 2, 'duration': 86, 'hour': 22},
#  {'day': 2, 'duration': 90, 'hour': 23},
#  {'day': 3, 'duration': 96, 'hour': 6},
#  {'day': 3, 'duration': 104, 'hour': 6},
#  {'day': 3, 'duration': 98, 'hour': 6},
#  {'day': 3, 'duration': 96, 'hour': 6},
#  {'day': 3, 'duration': 89, 'hour': 6},
#  {'day': 3, 'duration': 99, 'hour': 6},
#  {'day': 3, 'duration': 102, 'hour': 7},
#  {'day': 3, 'duration': 107, 'hour': 7},
#  {'day': 3, 'duration': 103, 'hour': 7},
#  {'day': 3, 'duration': 104, 'hour': 7},
#  {'day': 3, 'duration': 108, 'hour': 7},
#  {'day': 3, 'duration': 110, 'hour': 7},
#  {'day': 3, 'duration': 118, 'hour': 7},
#  {'day': 3, 'duration': 111, 'hour': 8},
#  {'day': 3, 'duration': 112, 'hour': 8},
#  {'day': 3, 'duration': 108, 'hour': 8},
#  {'day': 3, 'duration': 109, 'hour': 8},
#  {'day': 3, 'duration': 103, 'hour': 8},
#  {'day': 3, 'duration': 111, 'hour': 9},
#  {'day': 3, 'duration': 101, 'hour': 9},
#  {'day': 3, 'duration': 109, 'hour': 9},
#  {'day': 3, 'duration': 104, 'hour': 9},
#  {'day': 3, 'duration': 110, 'hour': 9},
#  {'day': 3, 'duration': 98, 'hour': 9},
#  {'day': 3, 'duration': 97, 'hour': 9},
#  {'day': 3, 'duration': 99, 'hour': 10},
#  {'day': 3, 'duration': 97, 'hour': 10},
#  {'day': 3, 'duration': 96, 'hour': 10},
#  {'day': 3, 'duration': 104, 'hour': 10},
#  {'day': 3, 'duration': 97, 'hour': 10},
#  {'day': 3, 'duration': 93, 'hour': 11},
#  {'day': 3, 'duration': 97, 'hour': 11},
#  {'day': 3, 'duration': 100, 'hour': 11},
#  {'day': 3, 'duration': 96, 'hour': 11},
#  {'day': 3, 'duration': 93, 'hour': 11},
#  {'day': 3, 'duration': 93, 'hour': 11},
#  {'day': 3, 'duration': 98, 'hour': 11},
#  {'day': 3, 'duration': 93, 'hour': 12},
#  {'day': 3, 'duration': 96, 'hour': 12},
#  {'day': 3, 'duration': 93, 'hour': 12},
#  {'day': 3, 'duration': 94, 'hour': 12},
#  {'day': 3, 'duration': 93, 'hour': 12},
#  {'day': 3, 'duration': 96, 'hour': 12},
#  {'day': 3, 'duration': 99, 'hour': 13},
#  {'day': 3, 'duration': 101, 'hour': 13},
#  {'day': 3, 'duration': 93, 'hour': 13},
#  {'day': 3, 'duration': 94, 'hour': 13},
#  {'day': 3, 'duration': 101, 'hour': 13},
#  {'day': 3, 'duration': 96, 'hour': 13},
#  {'day': 3, 'duration': 94, 'hour': 14},
#  {'day': 3, 'duration': 94, 'hour': 14},
#  {'day': 3, 'duration': 91, 'hour': 14},
#  {'day': 3, 'duration': 93, 'hour': 14},
#  {'day': 3, 'duration': 95, 'hour': 14},
#  {'day': 3, 'duration': 102, 'hour': 15},
#  {'day': 3, 'duration': 110, 'hour': 15},
#  {'day': 3, 'duration': 99, 'hour': 15},
#  {'day': 3, 'duration': 101, 'hour': 15},
#  {'day': 3, 'duration': 103, 'hour': 15},
#  {'day': 3, 'duration': 109, 'hour': 15},
#  {'day': 3, 'duration': 111, 'hour': 15},
#  {'day': 3, 'duration': 107, 'hour': 16},
#  {'day': 3, 'duration': 109, 'hour': 16},
#  {'day': 3, 'duration': 105, 'hour': 16},
#  {'day': 3, 'duration': 113, 'hour': 16},
#  {'day': 3, 'duration': 104, 'hour': 16},
#  {'day': 3, 'duration': 105, 'hour': 16},
#  {'day': 3, 'duration': 111, 'hour': 17},
#  {'day': 3, 'duration': 92, 'hour': 17},
#  {'day': 3, 'duration': 108, 'hour': 17},
#  {'day': 3, 'duration': 106, 'hour': 17},
#  {'day': 3, 'duration': 104, 'hour': 17},
#  {'day': 3, 'duration': 111, 'hour': 17},
#  {'day': 3, 'duration': 109, 'hour': 18},
#  {'day': 3, 'duration': 77, 'hour': 18},
#  {'day': 3, 'duration': 103, 'hour': 18},
#  {'day': 3, 'duration': 104, 'hour': 18},
#  {'day': 3, 'duration': 102, 'hour': 18},
#  {'day': 3, 'duration': 93, 'hour': 19},
#  {'day': 3, 'duration': 97, 'hour': 19},
#  {'day': 3, 'duration': 93, 'hour': 19},
#  {'day': 3, 'duration': 97, 'hour': 20},
#  {'day': 3, 'duration': 99, 'hour': 20},
#  {'day': 3, 'duration': 98, 'hour': 20},
#  {'day': 3, 'duration': 97, 'hour': 20},
#  {'day': 3, 'duration': 98, 'hour': 21},
#  {'day': 3, 'duration': 90, 'hour': 21},
#  {'day': 3, 'duration': 87, 'hour': 21},
#  {'day': 3, 'duration': 96, 'hour': 22},
#  {'day': 3, 'duration': 91, 'hour': 22},
#  {'day': 3, 'duration': 91, 'hour': 23},
#  {'day': 4, 'duration': 103, 'hour': 6},
#  {'day': 4, 'duration': 103, 'hour': 6},
#  {'day': 4, 'duration': 104, 'hour': 6},
#  {'day': 4, 'duration': 92, 'hour': 6},
#  {'day': 4, 'duration': 96, 'hour': 6},
#  {'day': 4, 'duration': 100, 'hour': 6},
#  {'day': 4, 'duration': 105, 'hour': 6},
#  {'day': 4, 'duration': 106, 'hour': 7},
#  {'day': 4, 'duration': 110, 'hour': 7},
#  {'day': 4, 'duration': 92, 'hour': 7},
#  {'day': 4, 'duration': 137, 'hour': 7},
#  {'day': 4, 'duration': 120, 'hour': 7},
#  {'day': 4, 'duration': 100, 'hour': 7},
#  {'day': 4, 'duration': 110, 'hour': 8},
#  {'day': 4, 'duration': 113, 'hour': 8},
#  {'day': 4, 'duration': 109, 'hour': 8},
#  {'day': 4, 'duration': 109, 'hour': 8},
#  {'day': 4, 'duration': 109, 'hour': 8},
#  {'day': 4, 'duration': 96, 'hour': 9},
#  {'day': 4, 'duration': 103, 'hour': 9},
#  {'day': 4, 'duration': 101, 'hour': 9},
#  {'day': 4, 'duration': 110, 'hour': 9},
#  {'day': 4, 'duration': 105, 'hour': 9},
#  {'day': 4, 'duration': 96, 'hour': 9},
#  {'day': 4, 'duration': 98, 'hour': 9},
#  {'day': 4, 'duration': 100, 'hour': 10},
#  {'day': 4, 'duration': 97, 'hour': 10},
#  {'day': 4, 'duration': 97, 'hour': 10},
#  {'day': 4, 'duration': 102, 'hour': 10},
#  {'day': 4, 'duration': 96, 'hour': 10},
#  {'day': 4, 'duration': 101, 'hour': 10},
#  {'day': 4, 'duration': 100, 'hour': 11},
#  {'day': 4, 'duration': 96, 'hour': 11},
#  {'day': 4, 'duration': 94, 'hour': 11},
#  {'day': 4, 'duration': 93, 'hour': 11},
#  {'day': 4, 'duration': 92, 'hour': 11},
#  {'day': 4, 'duration': 97, 'hour': 11},
#  {'day': 4, 'duration': 103, 'hour': 12},
#  {'day': 4, 'duration': 99, 'hour': 12},
#  {'day': 4, 'duration': 98, 'hour': 12},
#  {'day': 4, 'duration': 102, 'hour': 12},
#  {'day': 4, 'duration': 45, 'hour': 13},
#  {'day': 4, 'duration': 87, 'hour': 13},
#  {'day': 4, 'duration': 95, 'hour': 13},
#  {'day': 4, 'duration': 99, 'hour': 13},
#  {'day': 4, 'duration': 99, 'hour': 13},
#  {'day': 4, 'duration': 94, 'hour': 13},
#  {'day': 4, 'duration': 100, 'hour': 13},
#  {'day': 4, 'duration': 101, 'hour': 13},
#  {'day': 4, 'duration': 123, 'hour': 14},
#  {'day': 4, 'duration': 102, 'hour': 14},
#  {'day': 4, 'duration': 94, 'hour': 14},
#  {'day': 4, 'duration': 132, 'hour': 14},
#  {'day': 4, 'duration': 112, 'hour': 14},
#  {'day': 4, 'duration': 112, 'hour': 14},
#  {'day': 4, 'duration': 105, 'hour': 15},
#  {'day': 4, 'duration': 109, 'hour': 15},
#  {'day': 4, 'duration': 104, 'hour': 15},
#  {'day': 4, 'duration': 103, 'hour': 15},
#  {'day': 4, 'duration': 98, 'hour': 15},
#  {'day': 4, 'duration': 116, 'hour': 16},
#  {'day': 4, 'duration': 113, 'hour': 16},
#  {'day': 4, 'duration': 108, 'hour': 16},
#  {'day': 4, 'duration': 121, 'hour': 16},
#  {'day': 4, 'duration': 105, 'hour': 16},
#  {'day': 4, 'duration': 102, 'hour': 16},
#  {'day': 4, 'duration': 118, 'hour': 16},
#  {'day': 4, 'duration': 115, 'hour': 17},
#  {'day': 4, 'duration': 117, 'hour': 17},
#  {'day': 4, 'duration': 107, 'hour': 17},
#  {'day': 4, 'duration': 114, 'hour': 17},
#  {'day': 4, 'duration': 105, 'hour': 17},
#  {'day': 4, 'duration': 104, 'hour': 17},
#  {'day': 4, 'duration': 103, 'hour': 18},
#  {'day': 4, 'duration': 110, 'hour': 18},
#  {'day': 4, 'duration': 101, 'hour': 18},
#  {'day': 4, 'duration': 117, 'hour': 18},
#  {'day': 4, 'duration': 120, 'hour': 18},
#  {'day': 4, 'duration': 92, 'hour': 19},
#  {'day': 4, 'duration': 100, 'hour': 19},
#  {'day': 4, 'duration': 98, 'hour': 19},
#  {'day': 4, 'duration': 118, 'hour': 20},
#  {'day': 4, 'duration': 99, 'hour': 20},
#  {'day': 4, 'duration': 104, 'hour': 20},
#  {'day': 4, 'duration': 101, 'hour': 21},
#  {'day': 4, 'duration': 91, 'hour': 21},
#  {'day': 4, 'duration': 105, 'hour': 21},
#  {'day': 4, 'duration': 99, 'hour': 22},
#  {'day': 4, 'duration': 80, 'hour': 22},
#  {'day': 4, 'duration': 60, 'hour': 22}]

# %%
basetable = pd.DataFrame(rows)

# %%
basetable.duration.max()
# Out:
# 254

# %%
# boi = df.groupby(['VehicleJourneyID','TimeFrame']).size().reset_index().rename(columns={0:'count'})
# boi
# Out:
#      VehicleJourneyID   TimeFrame  count
# 0                4727  2012-11-19      1
# 1                4727  2012-11-21      1
# 2                4727  2012-11-22      1
# 3                4734  2012-11-20      1
# 4                4734  2012-11-22      1
# 5                4734  2012-11-23      1
# 6                4739  2012-11-23      1
# 7                4762  2012-11-26      1
# 8                4762  2012-11-30      1
# 9                4767  2012-11-30      1
# 10               4769  2012-11-27      1
# 11               4769  2012-11-28      1
# 12               4769  2012-11-29      2
# 13               4769  2012-11-30      1
# 14               4794  2012-11-23      1
# 15               4805  2012-11-23      1
# 16               4813  2012-11-23      1
# 17               4829  2012-11-30      1
# 18               4835  2012-11-19      1
# 19               4835  2012-11-21      1
# 20               4835  2012-11-23      2
# 21               4844  2012-11-30      1
# 22               4845  2012-11-21      1
# 23               4845  2012-11-23      1
# 24               4848  2012-11-29      1
# 25               4870  2012-11-27      1
# 26               4870  2012-11-28      1
# 27               4880  2012-11-26      1
# 28               4880  2012-11-27      1
# 29               4880  2012-11-28      1
# ...               ...         ...    ...
# 3674            16496  2012-11-11    303
# 3675            16497  2012-11-11    240
# 3676            16499  2012-11-11    286
# 3677            16500  2012-11-11      1
# 3678            16501  2012-11-11    267
# 3679            16502  2012-11-11      1
# 3680            16503  2012-11-11    220
# 3681            16504  2012-11-11    236
# 3682            16505  2012-11-11      1
# 3683            16506  2012-11-11    302
# 3684            16507  2012-11-11      1
# 3685            16508  2012-11-11    301
# 3686            16509  2012-11-11      1
# 3687            16510  2012-11-11    311
# 3688            16511  2012-11-11      1
# 3689            16512  2012-11-11    312
# 3690            16513  2012-11-11      1
# 3691            16514  2012-11-11    272
# 3692            16515  2012-11-11      1
# 3693            16516  2012-11-11    237
# 3694            16517  2012-11-11      1
# 3695            16519  2012-11-11    301
# 3696            16520  2012-11-11      1
# 3697            16521  2012-11-11    294
# 3698            16523  2012-11-11    165
# 3699           960340  2012-11-09      9
# 3700           964270  2012-11-26     18
# 3701           972736  2012-11-10     10
# 3702           982836  2012-11-19      2
# 3703           984482  2012-11-15    224
#
# [3704 rows x 3 columns]
