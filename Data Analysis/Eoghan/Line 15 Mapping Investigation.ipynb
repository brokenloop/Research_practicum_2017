# %% [markdown]
# # JourneyPatternID is a combination of Variant and Direction

# %%
import pandas as pd
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Import 15 Timetable

# %%
timetable = pd.read_csv("bus_data/static_data/master_timetable.csv")

# %%
#reassign columns to remove leading whitespace from variant column and name departure index
timetable.columns = ['departure_index', 'variant', 'day', 'departure', 'direction', 'line']

# %%
weekdayfifteentimetable = timetable.loc[(timetable['line'] == "15") & (timetable['day'] == "weekday")]
weekdayfifteentimetable.variant.value_counts()
# Out:
#  c    3
# Name: variant, dtype: int64

# %%
saturdayfifteentimetable = timetable.loc[(timetable['line'] == "15") & (timetable['day'] == "saturday")]
saturdayfifteentimetable.variant.value_counts()
# Out:
#  c    3
# Name: variant, dtype: int64

# %%
sundayfifteentimetable = timetable.loc[(timetable['line'] == "15") & (timetable['day'] == "sunday")]
sundayfifteentimetable.variant.value_counts()
# Out:
#  c    2
# Name: variant, dtype: int64

# %% [markdown]
# #### Refine by Direction

# %%
directions = (timetable.loc[(timetable['line'] == "15")]).direction.unique()
directions
# Out:
# array(['From Ballycullen Towards Clongriffin',
#        'From Clongriffin Towards Ballycullen'], dtype=object)

# %%
northbound_weekdayfifteentimetable = weekdayfifteentimetable.loc[(weekdayfifteentimetable['direction'] == directions[0])]
northbound_weekdayfifteentimetable.reset_index(inplace=True)

# %%
northbound_weekdayfifteentimetable
# Out:
#     index  departure_index variant      day departure  \
# 0    4422                0     NaN  weekday      6:00
# 1    4423                1     NaN  weekday      6:10
# 2    4424                2     NaN  weekday      6:20
# 3    4425                3     NaN  weekday      6:30
# 4    4426                4     NaN  weekday      6:40
# 5    4427                5     NaN  weekday      6:50
# 6    4428                6     NaN  weekday      7:00
# 7    4429                7     NaN  weekday      7:12
# 8    4430                8     NaN  weekday      7:25
# 9    4431                9     NaN  weekday      7:35
# 10   4432               10     NaN  weekday      7:45
# 11   4433               11     NaN  weekday      7:53
# 12   4434               12     NaN  weekday      8:00
# 13   4435               13     NaN  weekday      8:07
# 14   4436               14     NaN  weekday      8:15
# 15   4437               15     NaN  weekday      8:25
# 16   4438               16     NaN  weekday      8:40
# 17   4439               17     NaN  weekday      8:50
# 18   4440               18     NaN  weekday      9:00
# 19   4441               19     NaN  weekday      9:10
# 20   4442               20     NaN  weekday      9:20
# 21   4443               21     NaN  weekday      9:30
# 22   4444               22     NaN  weekday      9:40
# 23   4445               23     NaN  weekday      9:50
# 24   4446               24     NaN  weekday     10:00
# 25   4447               25     NaN  weekday     10:10
# 26   4448               26     NaN  weekday     10:20
# 27   4449               27     NaN  weekday     10:30
# 28   4450               28     NaN  weekday     10:40
# 29   4451               29     NaN  weekday     10:50
# ..    ...              ...     ...      ...       ...
# 62   4484               62     NaN  weekday     16:20
# 63   4485               63     NaN  weekday     16:30
# 64   4486               64     NaN  weekday     16:40
# 65   4487               65     NaN  weekday     16:50
# 66   4488               66     NaN  weekday     17:00
# 67   4489               67     NaN  weekday     17:10
# 68   4490               68     NaN  weekday     17:20
# 69   4491               69     NaN  weekday     17:30
# 70   4492               70     NaN  weekday     17:40
# 71   4493               71     NaN  weekday     17:50
# 72   4494               72     NaN  weekday     18:00
# 73   4495               73     NaN  weekday     18:10
# 74   4496               74     NaN  weekday     18:20
# 75   4497               75     NaN  weekday     18:30
# 76   4498               76     NaN  weekday     18:40
# 77   4499               77     NaN  weekday     18:50
# 78   4500               78     NaN  weekday     19:00
# 79   4501               79     NaN  weekday     19:20
# 80   4502               80     NaN  weekday     19:40
# 81   4503               81     NaN  weekday     20:00
# 82   4504               82     NaN  weekday     20:20
# 83   4505               83     NaN  weekday     20:40
# 84   4506               84     NaN  weekday     21:00
# 85   4507               85     NaN  weekday     21:20
# 86   4508               86     NaN  weekday     21:40
# 87   4509               87     NaN  weekday     22:00
# 88   4510               88     NaN  weekday     22:20
# 89   4511               89     NaN  weekday     22:40
# 90   4512               90     NaN  weekday     23:00
# 91   4513               91       c  weekday     23:20
#
#                                direction line
# 0   From Ballycullen Towards Clongriffin   15
# 1   From Ballycullen Towards Clongriffin   15
# 2   From Ballycullen Towards Clongriffin   15
# 3   From Ballycullen Towards Clongriffin   15
# 4   From Ballycullen Towards Clongriffin   15
# 5   From Ballycullen Towards Clongriffin   15
# 6   From Ballycullen Towards Clongriffin   15
# 7   From Ballycullen Towards Clongriffin   15
# 8   From Ballycullen Towards Clongriffin   15
# 9   From Ballycullen Towards Clongriffin   15
# 10  From Ballycullen Towards Clongriffin   15
# 11  From Ballycullen Towards Clongriffin   15
# 12  From Ballycullen Towards Clongriffin   15
# 13  From Ballycullen Towards Clongriffin   15
# 14  From Ballycullen Towards Clongriffin   15
# 15  From Ballycullen Towards Clongriffin   15
# 16  From Ballycullen Towards Clongriffin   15
# 17  From Ballycullen Towards Clongriffin   15
# 18  From Ballycullen Towards Clongriffin   15
# 19  From Ballycullen Towards Clongriffin   15
# 20  From Ballycullen Towards Clongriffin   15
# 21  From Ballycullen Towards Clongriffin   15
# 22  From Ballycullen Towards Clongriffin   15
# 23  From Ballycullen Towards Clongriffin   15
# 24  From Ballycullen Towards Clongriffin   15
# 25  From Ballycullen Towards Clongriffin   15
# 26  From Ballycullen Towards Clongriffin   15
# 27  From Ballycullen Towards Clongriffin   15
# 28  From Ballycullen Towards Clongriffin   15
# 29  From Ballycullen Towards Clongriffin   15
# ..                                   ...  ...
# 62  From Ballycullen Towards Clongriffin   15
# 63  From Ballycullen Towards Clongriffin   15
# 64  From Ballycullen Towards Clongriffin   15
# 65  From Ballycullen Towards Clongriffin   15
# 66  From Ballycullen Towards Clongriffin   15
# 67  From Ballycullen Towards Clongriffin   15
# 68  From Ballycullen Towards Clongriffin   15
# 69  From Ballycullen Towards Clongriffin   15
# 70  From Ballycullen Towards Clongriffin   15
# 71  From Ballycullen Towards Clongriffin   15
# 72  From Ballycullen Towards Clongriffin   15
# 73  From Ballycullen Towards Clongriffin   15
# 74  From Ballycullen Towards Clongriffin   15
# 75  From Ballycullen Towards Clongriffin   15
# 76  From Ballycullen Towards Clongriffin   15
# 77  From Ballycullen Towards Clongriffin   15
# 78  From Ballycullen Towards Clongriffin   15
# 79  From Ballycullen Towards Clongriffin   15
# 80  From Ballycullen Towards Clongriffin   15
# 81  From Ballycullen Towards Clongriffin   15
# 82  From Ballycullen Towards Clongriffin   15
# 83  From Ballycullen Towards Clongriffin   15
# 84  From Ballycullen Towards Clongriffin   15
# 85  From Ballycullen Towards Clongriffin   15
# 86  From Ballycullen Towards Clongriffin   15
# 87  From Ballycullen Towards Clongriffin   15
# 88  From Ballycullen Towards Clongriffin   15
# 89  From Ballycullen Towards Clongriffin   15
# 90  From Ballycullen Towards Clongriffin   15
# 91  From Ballycullen Towards Clongriffin   15
#
# [92 rows x 7 columns]

# %%
southbound_weekdayfifteentimetable = weekdayfifteentimetable.loc[(weekdayfifteentimetable['direction'] == directions[0])]
southbound_weekdayfifteentimetable.reset_index(inplace=True)

# %%
southbound_weekdayfifteentimetable.shape
# Out:
# (92, 7)

# %% [markdown]
# ## Import 15 Data

# %%
fifteen = pd.read_csv("bus_data/line_data/15.csv")
fifteen.columns = ["Timestamp", "LineID", "JourneyPatternID", "TimeFrame", 
              "VehicleJourneyID", "Lon", "Lat", "VehicleID", "StopID", 
              "AtStop", "HumanTime", "Day", "Hour", "Runtime"]

# %%
fifteen['HumanTime'] = pd.to_datetime(fifteen['HumanTime'])

# %% [markdown]
# #### number of journey pattern ids should equal number of directions + variations on each direction

# %%
journeypatterns = list(fifteen.JourneyPatternID.unique())

# %%
journeypatterns
# Out:
# [1, 1001, 1002, 2]

# %%
#Monday is 0, Sunday is 6
def get_day(x):
    if x.weekday() == 5:
        return "saturday"
    elif x.weekday() == 6:
        return "sunday"
    else:
        return "weekday"
    
fifteen["day"] = fifteen['HumanTime'].apply(get_day)

# %%
sunday = fifteen.loc[fifteen['day'] == "sunday"]
saturday = fifteen.loc[fifteen['day'] == "saturday"]
weekday = fifteen.loc[fifteen['day'] == "weekday"]

# %%
weekday.JourneyPatternID.value_counts()
# Out:
# 1       110972
# 1001    102739
# 1002       526
# 2          158
# Name: JourneyPatternID, dtype: int64

# %% [markdown]
# Extract Single Day and JourneyPatternID

# %%
saturday.JourneyPatternID.value_counts()
# Out:
# 1       12157
# 1001    11304
# 1002      166
# 2          42
# Name: JourneyPatternID, dtype: int64

# %%
sunday.JourneyPatternID.value_counts()
# Out:
# 1       7332
# 1001    6838
# 1002      31
# 2         22
# Name: JourneyPatternID, dtype: int64

# %% [markdown]
# Therefore there are 2 directions and 2 variations everyday

# %%
tuesday = fifteen.loc[(fifteen['TimeFrame'] == "2012-11-07")]
# Out:
# 1       2944
# 1001    2540
# 1002      13
# 2          2
# Name: JourneyPatternID, dtype: int64

# %%
tuesday_trips = tuesday.drop_duplicates("VehicleJourneyID", keep='first', inplace=False)
print("total number of trips on a single tuesday is:")
tuesday_trips.JourneyPatternID.value_counts().sum()
# Out:
# total number of trips on a single tuesday is:
# 183

# %%
print("which is almost the name as the number there ought to be on a single day:")
weekdayfifteentimetable.shape[0]
# Out:
# which is almost the name as the number there ought to be on a single day:
# 184

# %%
tuesday_trips = tuesday.drop_duplicates("VehicleJourneyID", keep='first', inplace=False)
print("But the JourneyPattern ID counts of those trips on a single tuesday are not evely divided:")
tuesday_trips.JourneyPatternID.value_counts()
# Out:
# But the JourneyPattern ID counts of those trips on a single tuesday are not evely divided:
# 1       132
# 1001     49
# 1002      1
# 2         1
# Name: JourneyPatternID, dtype: int64

# %% [markdown]
# ##### The JourneyPatternID "1" has too high a count to describe a single direction, it must describe 2.

# %%
tuesday_trips.JourneyPatternID.value_counts().sum()
# Out:
# 183

# %%
tuesday_trips_oneway = tuesday_trips.loc[(tuesday_trips['JourneyPatternID'] == 1)]
tuesday_trips_oneway
# Out:
#               Timestamp  LineID  JourneyPatternID   TimeFrame  \
# 5556  2012-11-07 06:40:28    2     6       59  weekday
# 5593  2012-11-07 06:50:50    2     6        0  weekday
# 5631  2012-11-07 07:00:45    2     7      260  weekday
# 5657  2012-11-07 07:06:52    2     7        0  weekday
# 5742  2012-11-07 07:25:44    2     7      121  weekday
# 5807  2012-11-07 07:36:50    2     7        0  weekday
# 5827  2012-11-07 07:40:23    2     7      639  weekday
# 5865  2012-11-07 07:46:22    2     7      270  weekday
# 5923  2012-11-07 07:56:12    2     7      742  weekday
# 5952  2012-11-07 08:00:50    2     8      659  weekday
# 5957  2012-11-07 08:01:51    2     8        0  weekday
# 6007  2012-11-07 08:08:48    2     8        0  weekday
# 6053  2012-11-07 08:16:39    2     8      181  weekday
# 6110  2012-11-07 08:25:24    2     8      178  weekday
# 6114  2012-11-07 08:25:53    2     8        0  weekday
# 6220  2012-11-07 08:41:48    2     8        0  weekday
# 6239  2012-11-07 08:44:46    2     8        0  weekday
# 6287  2012-11-07 08:51:30    2     8      397  weekday
# 6328  2012-11-07 08:56:38    2     8        0  weekday
# 6357  2012-11-07 09:01:05    2     9        0  weekday
# 6381  2012-11-07 09:04:43    2     9        0  weekday
# 6433  2012-11-07 09:12:41    2     9      322  weekday
# 6448  2012-11-07 09:14:46    2     9        0  weekday
# 6527  2012-11-07 09:24:43    2     9        0  weekday
# 6659  2012-11-07 09:44:50    2     9        0  weekday
# 6669  2012-11-07 09:46:55    2     9        0  weekday
# ...                   ...  ...   ...      ...      ...
# 9462  2012-11-07 17:34:47    2    17        0  weekday
# 9498  2012-11-07 17:41:12    2    17      117  weekday
# 9520  2012-11-07 17:44:44    2    17        0  weekday
# 9604  2012-11-07 17:57:14    2    17        0  weekday
# 9656  2012-11-07 18:04:33    2    18        0  weekday
# 9728  2012-11-07 18:14:13    2    18        0  weekday
# 9801  2012-11-07 18:22:35    2    18        0  weekday
# 9872  2012-11-07 18:32:28    2    18        0  weekday
# 9958  2012-11-07 18:45:43    2    18        0  weekday
# 10018 2012-11-07 18:53:16    2    18        0  weekday
# 10070 2012-11-07 19:03:13    2    19        0  weekday
# 10154 2012-11-07 19:17:10    2    19        0  weekday
# 10185 2012-11-07 19:22:58    2    19      157  weekday
# 10251 2012-11-07 19:34:44    2    19        0  weekday
# 10294 2012-11-07 19:44:51    2    19        0  weekday
# 10302 2012-11-07 19:46:04    2    19      464  weekday
# 10410 2012-11-07 20:17:23    2    20        0  weekday
# 10485 2012-11-07 20:34:44    2    20        0  weekday
# 10488 2012-11-07 20:35:31    2    20        0  weekday
# 10527 2012-11-07 20:50:51    2    20        0  weekday
# 10558 2012-11-07 21:01:59    2    21      387  weekday
# 10642 2012-11-07 21:27:07    2    21      456  weekday
# 10657 2012-11-07 21:34:50    2    21        0  weekday
# 10670 2012-11-07 21:41:28    2    21        0  weekday
# 10709 2012-11-07 21:54:35    2    21        0  weekday
# 10730 2012-11-07 22:05:31    2    22      642  weekday
# 10786 2012-11-07 22:24:58    2    22        0  weekday
# 10839 2012-11-07 22:44:36    2    22      600  weekday
# 10888 2012-11-07 23:04:24    2    23      359  weekday
# 10913 2012-11-07 23:14:36    2    23        0  weekday
#
# [132 rows x 15 columns]

# %% [markdown]
# ### It is very difficult to infer which of these is in which direction
#
# was there originally a direction collumn which was dropped which could be resused?
