# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import statsmodels.formula.api as sm

import pprint as pp

# %matplotlib inline

# %% [markdown]
# ## Reading Data & Formatting

# %%
df = pd.read_csv("bus_data/cleaned_data/line15.csv", low_memory=False, header=None)
df.columns = ["Timestamp", "LineID", "Direction", "JourneyPatternID", "TimeFrame", 
              "VehicleJourneyID", "Operator", "Congestion", "Lon", "Lat", 
              "Delay", "BlockID", "VehicleID", "StopID", "AtStop"]

# %%
#Select all columns of type 'object'
object_columns = df.select_dtypes(['object']).columns

#Convert selected columns to type 'category'
for column in object_columns:
    df[column] = df[column].astype('category')
    
# Convert other features to categorical
for column in ['LineID', 'VehicleJourneyID', 'Congestion', 'BlockID', 'VehicleID', 'AtStop']:
    df[column] = df[column].astype('category')

# %%
# Add column for human readable time
df['HumanTime'] = pd.to_datetime(df['Timestamp'], unit='us')

# %%
# Add day of week column
df['Day'] = df['HumanTime'].dt.dayofweek

# Add hour of day column
df['Hour'] = df['HumanTime'].dt.hour

# %%
# Dropping irrelevant columns
df = df.drop('BlockID', 1)
df = df.drop('Operator', 1)
df = df.drop('Delay', 1)
df = df.drop('Congestion', 1)

# %% [markdown]
# ## Separating journey patterns

# %%
patterns = df.JourneyPatternID.unique()

for pattern in patterns:
    print(pattern)
# Out:
# 00150001
# 00151001
# 015A1001
# 015A0001
# null
# nan
# 015B0002
# 015B1001
# 015A0002
# 015B0001
# 015B1002
# 015B0003
# 00151002
# 00150002
# 029A1001
# 066A0001
# 00400001
# 056A1001

# %%
# Choosing only line 00150001, for a single day
# newdf = df[(df.JourneyPatternID == '00150001') & (df.TimeFrame == '2012-11-26')]
newdf = df[(df.JourneyPatternID == '00150001')]
newdf.head(100)
# Out:
#             Timestamp LineID  Direction JourneyPatternID   TimeFrame  \
# 0    1352160000000000   15.0          0         00150001  2012-11-05
# 3    1352160010000000   15.0          0         00150001  2012-11-05
# 6    1352160019000000   15.0          0         00150001  2012-11-05
# 9    1352160031000000   15.0          0         00150001  2012-11-05
# 13   1352160039000000   15.0          0         00150001  2012-11-05
# 18   1352160049000000   15.0          0         00150001  2012-11-05
# 21   1352160059000000   15.0          0         00150001  2012-11-05
# 23   1352160069000000   15.0          0         00150001  2012-11-05
# 26   1352160079000000   15.0          0         00150001  2012-11-05
# 28   1352160090000000   15.0          0         00150001  2012-11-05
# 33   1352160100000000   15.0          0         00150001  2012-11-05
# 35   1352160110000000   15.0          0         00150001  2012-11-05
# 38   1352160120000000   15.0          0         00150001  2012-11-05
# 40   1352160128000000   15.0          0         00150001  2012-11-05
# 43   1352160142000000   15.0          0         00150001  2012-11-05
# 48   1352160160000000   15.0          0         00150001  2012-11-05
# 50   1352160169000000   15.0          0         00150001  2012-11-05
# 53   1352160179000000   15.0          0         00150001  2012-11-05
# 57   1352160199000000   15.0          0         00150001  2012-11-05
# 59   1352160209000000   15.0          0         00150001  2012-11-05
# 63   1352160217000000   15.0          0         00150001  2012-11-05
# 65   1352160219000000   15.0          0         00150001  2012-11-05
# 67   1352160231000000   15.0          0         00150001  2012-11-05
# 70   1352160240000000   15.0          0         00150001  2012-11-05
# 74   1352160262000000   15.0          0         00150001  2012-11-05
# 76  2012-11-06 00:04:30    1     0
# 81  2012-11-06 00:04:38    1     0
# 82  2012-11-06 00:04:40    1     0
# 85  2012-11-06 00:04:52    1     0
# 87  2012-11-06 00:05:00    1     0
# ..                  ...  ...   ...
# 231 2012-11-06 00:14:49    1     0
# 235 2012-11-06 00:15:10    1     0
# 239 2012-11-06 00:15:30    1     0
# 243 2012-11-06 00:15:40    1     0
# 245 2012-11-06 00:15:48    1     0
# 249 2012-11-06 00:16:10    1     0
# 253 2012-11-06 00:16:33    1     0
# 256 2012-11-06 00:16:39    1     0
# 258 2012-11-06 00:16:49    1     0
# 262 2012-11-06 00:17:09    1     0
# 266 2012-11-06 00:17:31    1     0
# 269 2012-11-06 00:17:37    1     0
# 272 2012-11-06 00:17:49    1     0
# 276 2012-11-06 00:18:09    1     0
# 280 2012-11-06 00:18:30    1     0
# 283 2012-11-06 00:18:38    1     0
# 285 2012-11-06 00:18:50    1     0
# 288 2012-11-06 00:19:10    1     0
# 291 2012-11-06 00:19:30    1     0
# 294 2012-11-06 00:19:38    1     0
# 296 2012-11-06 00:19:53    1     0
# 298 2012-11-06 00:20:09    1     0
# 300 2012-11-06 00:20:29    1     0
# 301 2012-11-06 00:20:39    1     0
# 304 2012-11-06 00:20:51    1     0
# 306 2012-11-06 00:21:09    1     0
# 308 2012-11-06 00:21:29    1     0
# 309 2012-11-06 00:21:38    1     0
# 312 2012-11-06 00:21:52    1     0
# 314 2012-11-06 00:22:10    1     0
#
# [100 rows x 14 columns]

# %%
stops = newdf.StopID.unique()

for stop in stops:
    print(stop)
# Out:
# 4870
# 4869
# 3007
# 6283
# 6282
# 6318
# 6319
# 7246
# 6320
# 4594
# 4595
# 4596
# 4563
# 1218
# 1270
# 1272
# 1273
# 1274
# 1275
# 1276
# 1219
# 1220
# 1221
# 664
# 665
# 666
# 1277
# 667
# 668
# 614
# 615
# 616
# 617
# 618
# 619
# 675
# 4415
# 4719
# 5190
# 348
# 403
# 746
# 844
# 1014
# 1015
# 1016
# 1017
# 1019
# 1020
# 1076
# 1077
# 1078
# 1081
# 1083
# 1085
# 1121
# 1079
# 1080
# 1122
# 1123
# 1124
# 1125
# 1127
# 1130
# 1140
# 1141
# 1142
# 1143
# 1144
# 1145
# 1018
# 1082
# 6326
# 6316
# 6335
# 1150
# 1164
# 4886
# 1154
# 1165
# 1151
# 6079
# 6285
# 6288
# 1155
# 299
# 497
# 790
# 6286
# 1153
# 4887
# 7245
# 1158
# 6317
# 6315
# 1166
# 946
# 4528
# 1152
# 7236
# 6287
# 1069
# 1157
# 6115

# %%
# drop duplicate rows
newdf = newdf.drop_duplicates(["TimeFrame", "VehicleJourneyID", "StopID"])

# drop rows where bus isn't at stop
newdf = newdf[(newdf.AtStop == 1) & (newdf.HumanTime.dt.hour == 4)]

# %%
# drop rows where bus isn't at stop
nightime = df[(df.HumanTime.dt.hour > 2) & (df.HumanTime.dt.hour < 6)]

# %%
nightime.tail()
# Out:
# Empty DataFrame
# Columns: [Timestamp, LineID, Direction, JourneyPatternID, TimeFrame, VehicleJourneyID, Lon, Lat, VehicleID, StopID, AtStop, HumanTime, Day, Hour]
# Index: []

# %%
# filter out routes which only have 1 stop. 
# This solves the problem of busses starting on the wrong side... 
newdf = newdf.groupby(['TimeFrame', 'VehicleJourneyID']).filter(lambda x: len(x) >= 3)

# %%
# Putting the first sightings of a vehiclejourneyid and timeframe combo timestamp into a dictionary

start_times = {}

# This gives you the first line anything has been seen by 
firstlines = newdf.groupby(["TimeFrame", "VehicleJourneyID"]).head(1)

# This iterates through them and assigns values to the dictionary
for index, row in firstlines.iterrows():
    start_times[row.TimeFrame, row.VehicleJourneyID] = {"time":row.Timestamp, "loc":[row.Lat, row.Lon]}

# %%
pp.pprint(start_times)
# Out:
# {}

# %%
locations = []

for x in start_times:
#     locations.append(start_times[x])
    print(start_times[x]["loc"][0], start_times[x]["loc"][1])

# %% [markdown]
# ## Problem - Not all busses start in the same spot!
#
# (5148 2012-11-26) doesn't start on the north side.
#
# This is how it's supposed to be! The ones that do start on the northside are phony.
#
# No, because (5141, 2012-11-26) starts on the north side and hits a bunch of stops. Why do we have north south both doing the same journey?
#
# 5148 (starts in south) doesn't actually hit any stops except 1...
# 5150 is the same
# 5156
# 5158
#
# Seems to be a pattern. The busses that start in the south don't actually service any stops. Why are they signalling that they're on the journeypattern?

# %% [markdown]
# ### Adding Runtime column
#
# This column will represent the number of seconds elapsed since the bus started along its journey

# %%
def add_runtime(row, mydict):
    # Takes a row and a dictionary of start times
    # returns time elapsed (seconds) between that row's timestamp and the start of the line
    start = mydict[row.TimeFrame, row.VehicleJourneyID]["time"]
    current = row.Timestamp
    return (current - start) // 1000000

newdf['Runtime'] = ""

# Applies this function to the newdf
newdf['Runtime'] = newdf.apply(lambda row: add_runtime(row, start_times),axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/danieljordan/anaconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     388                 result = np.empty(len(values), dtype=object)
# --> 389                 result[:] = values
#     390             except ValueError:
#
# ValueError: could not broadcast input array from shape (0,15) into shape (0)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /Users/danieljordan/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2463             try:
# -> 2464                 value = Series(value)
#    2465             except:
#
# /Users/danieljordan/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     242                 data = _sanitize_array(data, index, dtype, copy,
# --> 243                                        raise_cast_failure=True)
#     244
#
# /Users/danieljordan/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    2951         else:
# -> 2952             subarr = _asarray_tuplesafe(data, dtype=dtype)
#    2953
#
# /Users/danieljordan/anaconda3/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     391                 # we have a list-of-list
# --> 392                 result[:] = [tuple(x) for x in values]
#     393
#
# ValueError: cannot copy sequence with size 15 to array axis with dimension 0
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-c8b4e08f78ce> in <module>()
#       9
#      10 # Applies this function to the newdf
# ---> 11 newdf['Runtime'] = newdf.apply(lambda row: add_runtime(row, start_times),axis=1)
#
# /Users/danieljordan/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2417         else:
#    2418             # set column
# -> 2419             self._set_item(key, value)
#    2420
#    2421     def _setitem_slice(self, key, value):
#
# /Users/danieljordan/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2482         """
#    2483
# -> 2484         self._ensure_valid_index(value)
#    2485         value = self._sanitize_column(key, value)
#    2486         NDFrame._set_item(self, key, value)
#
# /Users/danieljordan/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2464                 value = Series(value)
#    2465             except:
# -> 2466                 raise ValueError('Cannot set a frame with no defined index '
#    2467                                  'and a value that cannot be converted to a '
#    2468                                  'Series')
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%