# %%
# general 
import datetime
import os

# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Importing and Cleaning Data

# %%
def read_data(data_file):
    df = pd.read_csv(data_file, low_memory=False, header=None)
    df.columns = ["Timestamp", "LineID", "JourneyPatternID", "TimeFrame", 
                  "VehicleJourneyID", "Lon", "Lat", "VehicleID", "StopID", 
                  "AtStop", "HumanTime", "Day", "Hour", "JourneyGroup", "Runtime"]
        
    return df

# %%
def read_weather(weather_file):
    weather = pd.read_csv(weather_file, low_memory=False)
    
    return weather

# %%
def clean_weather(weather):
    weather['datetime'] = pd.to_datetime(weather['date'])
    
    weather['Hour'] = weather['datetime'].dt.hour
    weather['Date'] = weather['datetime'].dt.date
    weather = weather.drop(['datetime'], axis=1)
    
    weather = weather[['Date', 'Hour', 'rain']]
    
    # replacing empty cells with 0, converting to float
    weather['rain'] = pd.to_numeric(weather['rain'], errors='coerce')
    weather['rain'].fillna(0, inplace=True)
    
    # renaming rain to Rain
    weather = weather.rename(columns={'rain': 'Rain'})

    # converting rain to boolean
    weather['Rain'] = weather['Rain'].apply(lambda x: 1 if (x >= 1) else 0)
    
    return weather

# %%
def clean_df(df):
    df['Date'] = pd.to_datetime(df['Timestamp'], unit='us')
    df['Date'] = df['Date'].dt.date
    
    return df

# %%
def merge_save(df, weather, write_file):
    
    # Merging rain info with bus data
    new_df = pd.merge(df, weather, how='left' , on=['Date','Hour'])
    
    if new_df.shape[0] != df.shape[0]:
        raise ValueError("Imperfect mapping")
    
    new_df.to_csv(write_file)

# %%
def main(read_directory, write_directory, weather_file):
    
    print("Cleaning weather data...")
    weather = read_weather(weather_file)
    weather = clean_weather(weather)
    
    for read_file in os.listdir(read_directory):
        if read_file.endswith(".csv"):

            data_file = read_directory + "/" + read_file
            print(data_file)
            
            df = read_data(data_file)
            df = clean_df(df)
            
            try:
                merge_save(df, weather, write_directory + "/" + read_file)
            except ValueError as e:
                print(e)     

            print("Finished", read_file)
            print()
    print("Finished main!")

# %%
read_directory = "bus_data/clean_data3"
write_directory = "bus_data/clean_data4"
weather_file = "bus_data/hourly_weather_data.csv"

main(read_directory, write_directory, weather_file)
# Out:
# Cleaning weather data...
# bus_data/clean_data3/1.csv
# Finished 1.csv
#
# bus_data/clean_data3/104.csv
# Finished 104.csv
#
# bus_data/clean_data3/11.csv
# Finished 11.csv
#
# bus_data/clean_data3/111.csv
# Finished 111.csv
#
# bus_data/clean_data3/114.csv
# Finished 114.csv
#
# bus_data/clean_data3/116.csv
# Finished 116.csv
#
# bus_data/clean_data3/118.csv
# Finished 118.csv
#
# bus_data/clean_data3/120.csv
# Finished 120.csv
#
# bus_data/clean_data3/123.csv
# Finished 123.csv
#
# bus_data/clean_data3/13.csv
# Finished 13.csv
#
# bus_data/clean_data3/130.csv
# Finished 130.csv
#
# bus_data/clean_data3/14.csv
# Finished 14.csv
#
# bus_data/clean_data3/140.csv
# Finished 140.csv
#
# bus_data/clean_data3/142.csv
# Finished 142.csv
#
# bus_data/clean_data3/145.csv
# Finished 145.csv
#
# bus_data/clean_data3/14C.csv
# Finished 14C.csv
#
# bus_data/clean_data3/15.csv
# Finished 15.csv
#
# bus_data/clean_data3/150.csv
# Finished 150.csv
#
# bus_data/clean_data3/151.csv
# Finished 151.csv
#
# bus_data/clean_data3/15A.csv
# Finished 15A.csv
#
# bus_data/clean_data3/15B.csv
# Finished 15B.csv
#
# bus_data/clean_data3/16.csv
# Finished 16.csv
#
# bus_data/clean_data3/161.csv
# Finished 161.csv
#
# bus_data/clean_data3/16C.csv
# Finished 16C.csv
#
# bus_data/clean_data3/17.csv
# Finished 17.csv
#
# bus_data/clean_data3/17A.csv
# Finished 17A.csv
#
# bus_data/clean_data3/184.csv
# Finished 184.csv
#
# bus_data/clean_data3/185.csv
# Finished 185.csv
#
# bus_data/clean_data3/220.csv
# Finished 220.csv
#
# bus_data/clean_data3/236.csv
# Finished 236.csv
#
# bus_data/clean_data3/239.csv
# Finished 239.csv
#
# bus_data/clean_data3/25.csv
# Finished 25.csv
#
# bus_data/clean_data3/25A.csv
# Finished 25A.csv
#
# bus_data/clean_data3/25X.csv
# Finished 25X.csv
#
# bus_data/clean_data3/26.csv
# Finished 26.csv
#
# bus_data/clean_data3/27.csv
# Finished 27.csv
#
# bus_data/clean_data3/270.csv
# Finished 270.csv
#
# bus_data/clean_data3/27A.csv
# Finished 27A.csv
#
# bus_data/clean_data3/27X.csv
# Finished 27X.csv
#
# bus_data/clean_data3/29A.csv
# Finished 29A.csv
#
# bus_data/clean_data3/31.csv
# Finished 31.csv
#
# bus_data/clean_data3/31A.csv
# Finished 31A.csv
#
# bus_data/clean_data3/31B.csv
# Finished 31B.csv
#
# bus_data/clean_data3/32.csv
# Finished 32.csv
#
# bus_data/clean_data3/32A.csv
# Finished 32A.csv
#
# bus_data/clean_data3/32B.csv
# Finished 32B.csv
#
# bus_data/clean_data3/32X.csv
# Finished 32X.csv
#
# bus_data/clean_data3/33.csv
# Finished 33.csv
#
# bus_data/clean_data3/33A.csv
# Finished 33A.csv
#
# bus_data/clean_data3/33B.csv
# Finished 33B.csv
#
# bus_data/clean_data3/33X.csv
# Finished 33X.csv
#
# bus_data/clean_data3/37.csv
# Finished 37.csv
#
# bus_data/clean_data3/38.csv
# Finished 38.csv
#
# bus_data/clean_data3/38A.csv
# Finished 38A.csv
#
# bus_data/clean_data3/38B.csv
# Finished 38B.csv
#
# bus_data/clean_data3/39.csv
# Finished 39.csv
#
# bus_data/clean_data3/40.csv
# Finished 40.csv
#
# bus_data/clean_data3/40B.csv
# Finished 40B.csv
#
# bus_data/clean_data3/40D.csv
# Finished 40D.csv
#
# bus_data/clean_data3/41.csv
# Finished 41.csv
#
# bus_data/clean_data3/41A.csv
# Finished 41A.csv
#
# bus_data/clean_data3/41C.csv
# Finished 41C.csv
#
# bus_data/clean_data3/41X.csv
# Finished 41X.csv
#
# bus_data/clean_data3/42.csv
# Finished 42.csv
#
# bus_data/clean_data3/43.csv
# Finished 43.csv
#
# bus_data/clean_data3/44.csv
# Finished 44.csv
#
# bus_data/clean_data3/44B.csv
# Finished 44B.csv
#
# bus_data/clean_data3/45A.csv
# Finished 45A.csv
#
# bus_data/clean_data3/46A.csv
# Finished 46A.csv
#
# bus_data/clean_data3/46E.csv
# Finished 46E.csv
#
# bus_data/clean_data3/47.csv
# Finished 47.csv
#
# bus_data/clean_data3/49.csv
# Finished 49.csv
#
# bus_data/clean_data3/51D.csv
# Finished 51D.csv
#
# bus_data/clean_data3/51X.csv
# Finished 51X.csv
#
# bus_data/clean_data3/53.csv
# Finished 53.csv
#
# bus_data/clean_data3/54A.csv
# Finished 54A.csv
#
# bus_data/clean_data3/56A.csv
# Finished 56A.csv
#
# bus_data/clean_data3/59.csv
# Finished 59.csv
#
# bus_data/clean_data3/61.csv
# Finished 61.csv
#
# bus_data/clean_data3/63.csv
# Finished 63.csv
#
# bus_data/clean_data3/65.csv
# Finished 65.csv
#
# bus_data/clean_data3/65B.csv
# Finished 65B.csv
#
# bus_data/clean_data3/66.csv
# Finished 66.csv
#
# bus_data/clean_data3/66B.csv
# Finished 66B.csv
#
# bus_data/clean_data3/66X.csv
# Finished 66X.csv
#
# bus_data/clean_data3/67.csv
# Finished 67.csv
#
# bus_data/clean_data3/67X.csv
# Finished 67X.csv
#
# bus_data/clean_data3/68.csv
# Finished 68.csv
#
# bus_data/clean_data3/68A.csv
# Finished 68A.csv
#
# bus_data/clean_data3/69.csv
# Finished 69.csv
#
# bus_data/clean_data3/69X.csv
# Finished 69X.csv
#
# bus_data/clean_data3/7.csv
# Finished 7.csv
#
# bus_data/clean_data3/70.csv
# Finished 70.csv
#
# bus_data/clean_data3/747.csv
# Finished 747.csv
#
# bus_data/clean_data3/75.csv
# Finished 75.csv
#
# bus_data/clean_data3/76.csv
# Finished 76.csv
#
# bus_data/clean_data3/76A.csv
# Finished 76A.csv
#
# bus_data/clean_data3/77A.csv
# Finished 77A.csv
#
# bus_data/clean_data3/79.csv
# Finished 79.csv
#
# bus_data/clean_data3/79A.csv
# Finished 79A.csv
#
# bus_data/clean_data3/7B.csv
# Finished 7B.csv
#
# bus_data/clean_data3/7D.csv
# Finished 7D.csv
#
# bus_data/clean_data3/8.csv
# Finished 8.csv
#
# bus_data/clean_data3/83.csv
# Finished 83.csv
#
# bus_data/clean_data3/83A.csv
# Finished 83A.csv
#
# bus_data/clean_data3/84.csv
# Finished 84.csv
#
# bus_data/clean_data3/84A.csv
# Finished 84A.csv
#
# bus_data/clean_data3/84X.csv
# Finished 84X.csv
#
# bus_data/clean_data3/9.csv
# Finished 9.csv
#
# bus_data/clean_data3/PP07.csv
# Finished PP07.csv
#
# Finished main!

# %%
line = "15"

# %%
# Read in our data
df = pd.read_csv("bus_data/clean_data3/" + line + ".csv", low_memory=False, header=None)
df.columns = ["Timestamp", "LineID", "JourneyPatternID", "TimeFrame", 
              "VehicleJourneyID", "Lon", "Lat", "VehicleID", "StopID", 
              "AtStop", "HumanTime", "Day", "Hour", "JourneyGroup", "Runtime"]

# %%
df.head()
# Out:
#           Timestamp  LineID  JourneyPatternID   TimeFrame  VehicleJourneyID  \
# 0  1352182204000000      15                 1  2012-11-06              5899
# 1  1352192390000000      15                 1  2012-11-06              5828
# 2  1352192858000000      15                 1  2012-11-06              5835
# 3  1352193393000000      15                 1  2012-11-06              5853
# 4  1352194244000000      15                 1  2012-11-06              5878
#
#         Lon        Lat  VehicleID  StopID  AtStop            HumanTime  Day  \
# 0 -6.151132  53.402328      33498    6318       0  2012-11-06 06:10:04    1
# 1 -6.150883  53.402351      33523    6318       1  2012-11-06 08:59:50    1
# 2 -6.150987  53.402309      33254    6318       1  2012-11-06 09:07:38    1
# 3 -6.150987  53.402309      33209    6318       1  2012-11-06 09:16:33    1
# 4 -6.151132  53.402328      33020    6318       0  2012-11-06 09:30:44    1
#
#    Hour    JourneyGroup  Runtime
# 0     6  2012-11-065899        0
# 1     8  2012-11-065828        0
# 2     9  2012-11-065835        0
# 3     9  2012-11-065853        0
# 4     9  2012-11-065878        0

# %%
# read in weather data

weather = pd.read_csv("bus_data/hourly_weather_data.csv", low_memory=False)
#Read in the data from a csv file using Pandas
weather.tail()
# Out:
#                     date  ind rain  ind.1  temp  ind.2  wetb dewpt vappr rhum  \
# 86611  30-jun-2017 20:00    0  0.0      0  13.4      0  10.7   8.0  10.7   69
# 86612  30-jun-2017 21:00    0  0.0      0  11.4      0  10.0   8.5  11.1   82
# 86613  30-jun-2017 22:00    0  0.0      0   9.7      0   8.8   7.7  10.5   87
# 86614  30-jun-2017 23:00    0  0.0      0   8.2      0   7.8   7.2  10.1   93
# 86615  01-jul-2017 00:00    0  0.0      0   8.2      0   7.8   7.2  10.2   93
#
#           msl
# 86611  1016.5
# 86612  1017.2
# 86613  1017.6
# 86614  1017.9
# 86615  1018.2

# %% [markdown]
# ### Weather Info
#
# Station Name: PhoenixPark
# Station Height: 48 M
# Latitude:53.358  ,Longitude: -6.342
#
#
# date:  -  Date and Time (utc)
# rain:  -  Precipitation Amount (mm)
# temp:  -  Air Temperature (C)
# wetb:  -  Wet Bulb Temperature (C)
# dewpt: -  Dew Point Temperature (C)
# vappr: -  Vapour Pressure (hPa)
# rhum:  -  Relative Humidity (%)
# msl:   -  Mean Sea Level Pressure (hPa)
# ind:   -  Indicator

# %%
weather['datetime'] = pd.to_datetime(weather['date'])

# %%
weather.head()
# Out:
#                 date  ind rain  ind.1 temp  ind.2 wetb dewpt vappr rhum msl  \
# 0  31-may-2007 01:00   -1           4           4
# 1  31-may-2007 02:00   -1           4           4
# 2  31-may-2007 03:00   -1           4           4
# 3  31-may-2007 04:00   -1           4           4
# 4  31-may-2007 05:00   -1           4           4
#
#              datetime
# 0 2007-05-31 01:00:00
# 1 2007-05-31 02:00:00
# 2 2007-05-31 03:00:00
# 3 2007-05-31 04:00:00
# 4 2007-05-31 05:00:00

# %%
weather['Hour'] = weather['datetime'].dt.hour
weather['Date'] = weather['datetime'].dt.date
weather = weather.drop(['datetime'], axis=1)

# %%
# Dropping everything we don't want from weather 

weather = weather[['Date', 'Hour', 'rain']]

# %%
weather.head()
# Out:
#          Date  Hour rain
# 0  2007-05-31     1
# 1  2007-05-31     2
# 2  2007-05-31     3
# 3  2007-05-31     4
# 4  2007-05-31     5

# %% [markdown]
# ## Merging data & weather

# %%
df['Date'] = pd.to_datetime(df['Timestamp'], unit='us')
df['Date'] = df['Date'].dt.date

# %%
# replacing empty cells with 0, converting to float
weather['rain'] = pd.to_numeric(weather['rain'], errors='coerce')
weather['rain'].fillna(0, inplace=True)

# %%
# Merging rain info with bus data
new_df = pd.merge(df, weather, how='left' , on=['Date','Hour'])
