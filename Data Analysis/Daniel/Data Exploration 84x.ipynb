# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import statsmodels.formula.api as sm

# %matplotlib inline

# %%
df = pd.read_csv("bus_data/line_data/84X.csv", low_memory=False, header=None)
df.columns = ["Timestamp", "LineID", "JourneyPatternID", "TimeFrame", 
              "VehicleJourneyID", "Lon", "Lat", 
              "VehicleID", "StopID", "AtStop", "HumanTime", "Day", "Hour", "Runtime"]

# %%
df.tail(100)
# Out:
#               Timestamp LineID  JourneyPatternID   TimeFrame  \
# 10275  1359616407000000    84X              1002  2013-01-31
# 10276  1359616463000000    84X              1001  2013-01-31
# 10277  1359616463000000    84X              1002  2013-01-31
# 10278  1359616545000000    84X              1002  2013-01-31
# 10279  1359616598000000    84X              1001  2013-01-31
# 10280  1359616684000000    84X              1002  2013-01-31
# 10281  1359616727000000    84X              1002  2013-01-31
# 10282  1359616739000000    84X              1001  2013-01-31
# 10283  1359616763000000    84X              1002  2013-01-31
# 10284  1359616819000000    84X              1001  2013-01-31
# 10285  1359616843000000    84X              1001  2013-01-31
# 10286  1359616959000000    84X              1001  2013-01-31
# 10287  1359616966000000    84X              1002  2013-01-31
# 10288  1359616984000000    84X              1002  2013-01-31
# 10289  1359617046000000    84X              1001  2013-01-31
# 10290  1359617124000000    84X              1002  2013-01-31
# 10291  1359617183000000    84X              1002  2013-01-31
# 10292  1359617264000000    84X              1001  2013-01-31
# 10293  1359617304000000    84X              1002  2013-01-31
# 10294  1359617340000000    84X              1001  2013-01-31
# 10295  1359617365000000    84X              1002  2013-01-31
# 10296  1359617405000000    84X              1002  2013-01-31
# 10297  1359617464000000    84X              1002  2013-01-31
# 10298  1359617620000000    84X              1001  2013-01-31
# 10299  1359617860000000    84X              1001  2013-01-31
# 10300  1359617864000000    84X              1002  2013-01-31
# 10301  1359617885000000    84X              1002  2013-01-31
# 10302  1359617924000000    84X              1002  2013-01-31
# 10303  1359617938000000    84X              1002  2013-01-31
# 10304  1359618025000000    84X              1002  2013-01-31
# ...                 ...    ...               ...         ...
# 10345  1359620206000000    84X              1002  2013-01-31
# 10346  1359620277000000    84X              1002  2013-01-31
# 10347  1359620294000000    84X              1002  2013-01-31
# 10348  1359620310000000    84X              1002  2013-01-31
# 10349  1359620592000000    84X              1002  2013-01-31
# 10350  1359620773000000    84X              1002  2013-01-31
# 10351  1359620924000000    84X              1002  2013-01-31
# 10352  1359621085000000    84X              1002  2013-01-31
# 10353  1359621143000000    84X              1002  2013-01-31
# 10354  1359621201000000    84X              1002  2013-01-31
# 10355  1359621205000000    84X              1002  2013-01-31
# 10356  1359621211000000    84X              1002  2013-01-31
# 10357  1359621349000000    84X              1002  2013-01-31
# 10358  1359621374000000    84X              1002  2013-01-31
# 10359  1359621442000000    84X              1002  2013-01-31
# 10360  1359621455000000    84X              1002  2013-01-31
# 10361  1359621568000000    84X              1002  2013-01-31
# 10362  1359621641000000    84X              1002  2013-01-31
# 10363  1359621774000000    84X              1002  2013-01-31
# 10364  1359621803000000    84X              1002  2013-01-31
# 10355  2013-01-31 08:33:25    3     8     3159
# 10356  2013-01-31 08:33:31    3     8     4804
# 10357  2013-01-31 08:35:49    3     8     3303
# 10358  2013-01-31 08:36:14    3     8     4967
# 10359  2013-01-31 08:37:22    3     8     2358
# 10360  2013-01-31 08:37:35    3     8     5048
# 10361  2013-01-31 08:39:28    3     8     5161
# 10362  2013-01-31 08:40:41    3     8     2557
# 10363  2013-01-31 08:42:54    3     8     3728
# 10364  2013-01-31 08:43:23    3     8     2719
# 10365  2013-01-31 08:48:22    3     8     3018
# 10366  2013-01-31 08:51:13    3     8     3189
# 10367  2013-01-31 08:51:43    3     8     4257
# 10368  2013-01-31 08:57:39    3     8     3575
# 10369  2013-01-31 09:05:07    3     9     5061
# 10370  2013-01-31 09:17:43    3     9     4779
# 10371  2013-01-31 10:35:48    3    10      342
# 10372  2013-01-31 10:50:27    3    10     1221
# 10373  2013-01-31 10:55:55    3    10     1549
# 10374  2013-01-31 11:30:07    3    11     3601
#
# [100 rows x 14 columns]

# %%
df.JourneyPatternID.unique()
# Out:
# array([1001, 1002,    1,    2])

# %%
df.shape
# Out:
# (10375, 14)

# %%
df.dtypes
# Out:
# Timestamp             int64
# LineID                int64
# Direction             int64
# JourneyPatternID     object
# TimeFrame            object
# VehicleJourneyID      int64
# Operator             object
# Congestion            int64
# Lon                 float64
# Lat                 float64
# Delay                 int64
# BlockID               int64
# VehicleID             int64
# StopID               object
# AtStop                int64
# dtype: object

# %%
df.head(100)
# Out:
#              Timestamp LineID  Direction JourneyPatternID   TimeFrame  \
# 0  2012-11-06 00:00:00     15          0         00150001  2012-11-05
# 1  2012-11-06 00:00:04     15          0         00151001  2012-11-05
# 2  2012-11-06 00:00:04     15          0         015A1001  2012-11-05
# 3  2012-11-06 00:00:10     15          0         00150001  2012-11-05
# 4  2012-11-06 00:00:12     15          0         015A0001  2012-11-05
# 5  2012-11-06 00:00:17     15          0             null  2012-11-05
# 6  2012-11-06 00:00:19     15          0         00150001  2012-11-05
# 7  2012-11-06 00:00:23     15          0         00151001  2012-11-05
# 8  2012-11-06 00:00:23     15          0         015A1001  2012-11-05
# 9  2012-11-06 00:00:31     15          0         00150001  2012-11-05
# 10 2012-11-06 00:00:33     15          0         015A0001  2012-11-05
# 11 2012-11-06 00:00:35     15          0             null  2012-11-05
# 12 2012-11-06 00:00:39     15          0         00151001  2012-11-05
# 13 2012-11-06 00:00:39     15          0         00150001  2012-11-05
# 14 2012-11-06 00:00:39     15          0         015A1001  2012-11-05
# 15 2012-11-06 00:00:39     15          0             null  2012-11-05
# 16 2012-11-06 00:00:45     15          0         00151001  2012-11-05
# 17 2012-11-06 00:00:45     15          0         015A1001  2012-11-05
# 18 2012-11-06 00:00:49     15          0         00150001  2012-11-05
# 19 2012-11-06 00:00:53     15          0         015A0001  2012-11-05
# 20 2012-11-06 00:00:53     15          0             null  2012-11-05
# 97             5929       HN          0 -6.214650  53.410034    401   15105
# 98             5843       RD          0 -6.320500  53.289383   -323   15021
# 99             5929       HN          0 -6.218250  53.410515    401   15105
#
#    VehicleID StopID AtStop  Day  Hour
# 0      33210   4870      0    1     0
# 1      33502   6317      1    1     0
# 2      33469   2499      0    1     0
# 3      33254   4869      0    1     0
# 4      33020   1102      0    1     0
# 5      33484   6280      0    1     0
# 6      33210   4870      0    1     0
# 7      33502   6317      1    1     0
# 8      33469   2499      0    1     0
# 9      33254   4869      0    1     0
# 10     33020   1102      0    1     0
# 11     33484   6280      0    1     0
# 12     33502   6317      1    1     0
# 13     33210   4870      0    1     0
# 14     33469   7216      0    1     0
# 15     33484   6280      0    1     0
# 16     33502   6317      1    1     0
# 17     33469   7216      0    1     0
# 18     33254   4870      0    1     0
# 19     33020   1103      0    1     0
# 20     33484   6280      0    1     0
# 21     33210   4870      0    1     0
# 22     33502   6317      1    1     0
# 23     33254   3007      0    1     0
# 24     33020   1103      0    1     0
# 25     33484   6280      0    1     0
# 26     33210   4870      0    1     0
# 27     33502   6317      1    1     0
# 28     33254   3007      0    1     0
# 29     33020   1103      0    1     0
# ..       ...    ...    ...  ...   ...
# 70     33210   4870      0    1     0
# 71     33502   6317      1    1     0
# 72     33020   1103      0    1     0
# 73     33484   6280      0    1     0
# 74     33210   4870      0    1     0
# 75     33502   6317      1    1     0
# 76     33254   6282      1    1     0
# 77     33020   1103      0    1     0
# 78     33484   6280      0    1     0
# 79     33502   6317      1    1     0
# 80     33484   6280      0    1     0
# 81     33254   6282      1    1     0
# 82     33210   4870      0    1     0
# 83     33502   6317      1    1     0
# 84     33020   1103      0    1     0
# 85     33254   6282      1    1     0
# 86     33484   6280      0    1     0
# 87     33210   4870      0    1     0
# 88     33502   6317      1    1     0
# 89     33254   6282      1    1     0
# 90     33020   1103      0    1     0
# 91     33484   6280      0    1     0
# 92     33210   4870      0    1     0
# 93     33502   6317      1    1     0
# 94     33254   6282      1    1     0
# 95     33020   1103      0    1     0
# 96     33484   6280      0    1     0
# 97     33502   6317      1    1     0
# 98     33254   6282      1    1     0
# 99     33502   6317      1    1     0
#
# [100 rows x 17 columns]

# %%
#Select all columns of type 'object'
object_columns = df.select_dtypes(['object']).columns

# %%
#Convert selected columns to type 'category'
for column in object_columns:
    df[column] = df[column].astype('category')

# %%
# Convert Unix timestamp to datetime

# Take uneccesary trailing zeroes off of unix timestamp. 
df['Timestamp'] = df['Timestamp'].apply(lambda x: x//1000000)

# Convert the timestamp
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')

# %%
# Add day of week column
df['Day'] = df['Timestamp'].dt.dayofweek

# %%
# Add hour of day column
df['Hour'] = df['Timestamp'].dt.hour

# %%
# Descriptive stats for categorical features
df.select_dtypes(['category']).describe().T
# Out:
#                     count unique         top     freq
# JourneyPatternID  2254287     15    00150001   607458
# TimeFrame         2254343     26  2012-11-07   104579
# Operator          2254343      5          RD  1594991
# StopID            2254343    250        6282   125537

# %%
# Descriptive stats for continuous features
df.describe().T
# Out:
#                       count          mean           std           min  \
# LineID            2254343.0     15.000000      0.000000     15.000000
# Direction         2254343.0      0.000000      0.000000      0.000000
# VehicleJourneyID  2254343.0   6298.909057  24939.675830   2564.000000
# Congestion        2254343.0      0.024897      0.155811      0.000000
# Lon               2254343.0     -6.260996      0.050541     -6.387784
# Lat               2254343.0     53.331982      0.040214     53.186035
# Delay             2254343.0     -6.497476    473.516670 -14136.000000
# BlockID           2254343.0  15041.411825    805.495302  15001.000000
# VehicleID         2254343.0  32641.225763   2483.145428  24549.000000
# AtStop            2254343.0      0.236423      0.424885      0.000000
# Day               2254343.0      2.581871      1.728277      0.000000
# Hour              2254343.0     13.789241      4.857141      0.000000
#
#                            25%           50%           75%            max
# LineID               15.000000     15.000000     15.000000      15.000000
# Direction             0.000000      0.000000      0.000000       0.000000
# VehicleJourneyID   3189.000000   5220.000000   5881.000000  997396.000000
# Congestion            0.000000      0.000000      0.000000       1.000000
# Lon                  -6.300231     -6.263592     -6.236675      -6.100584
# Lat                  53.304447     53.333710     53.348286      53.421665
# Delay              -191.000000      0.000000    136.000000   10882.000000
# BlockID           15010.000000  15020.000000  15032.000000  150099.000000
# VehicleID         33020.000000  33459.000000  33493.000000   40033.000000
# AtStop                0.000000      0.000000      0.000000       1.000000
# Day                   1.000000      3.000000      4.000000       6.000000
# Hour                 10.000000     14.000000     18.000000      23.000000

# %%
# Convert some features to categorical
for column in ['LineID', 'VehicleJourneyID', 'Congestion', 'BlockID', 'VehicleID', 'AtStop']:
    df[column] = df[column].astype('category')

# %%
vehicledf.groupby(vehicledf.VehicleJourneyID)
vehicledf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-1a7c1c1073d5> in <module>()
# ----> 1 vehicledf.groupby(vehicledf.VehicleJourneyID)
#       2 vehicledf
#
# NameError: name 'vehicledf' is not defined

# %%
vehicledf = df[(df.VehicleJourneyID == '00151001') & (df.VehicleID == 33210) & (df.AtStop == 1) & (df.TimeFrame == "2012-11-07")]

# vehicledf = vehicledf.drop_duplicates('StopID')

# %%
pd.set_option('display.max_rows', 20)
vehicledf

# %%
# Endings = df.JourneyPatternID.str.slice([4])

# %%
df15 = df[(df.LineID == 15)]
df15.head()

# %%
df15.JourneyPatternID.value_counts()

# %%
stops = df15.drop_duplicates('StopID')
stops = stops['StopID', 'Diretc']
stops = stops.reset_index(drop='True')

# %%
# df_unusual = df.JourneyPatternID.astype(str).str.slice([4::])

# %%
df_unusual.astype(str)

# %%
stops

# %%
stopdict = {}
for stop in stops:
    row = df[df.StopID == stop].iloc[0]
    stopdict[stop] = [row["Lon"], row["Lat"]]

# %%
stopdict

# %%
df["Congestion"] = df[column].astype('int64')

# %%
continuous_features = ["Timestamp", "LonWGS84", "LatWGS84", "Delay", "Congestion"]

# %%
# Calculate correlation of all pairs of continuous features
corr = df[continuous_features].corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom colormap - blue and red
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, annot=True, mask=mask, cmap=cmap, vmax=1, vmin=-1,
            square=True, xticklabels=True, yticklabels=True,
            linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
plt.yticks(rotation = 0)
plt.xticks(rotation = 45)

# %%
df.plot(kind='scatter', x='Delay', y='Congestion')
# plt.savefig("images/congestion_delay_scatter.png")

# %%
categorical_columns = ["LineID", "JourneyPatternID", "TimeFrame", "VehicleJourneyID", 
                       "Operator", "Congestion", "BlockID", "VehicleID", "StopID", "AtStop"]
# for col in categorical_columns:
#     df[col].value_counts().plot(kind='bar')

# %%
df['Congestion'].value_counts().plot(kind='bar')
# plt.savefig("images/congestion_bar.png")

# %%
df["Delay"].hist(figsize=(10, 5), bins=100, range=[-2000, 2000])
# plt.savefig('images/delay_hist.png')

# %%
plt.figure(figsize=(10, 10))
df["Delay"].plot(kind='box')

# %%
def stacked_plot(clean_df, f1, f2):
    # Compare f2 and f1

    # Find unique values in f2
    featured = pd.unique(clean_df[f2].ravel())

    # Insert a new column called 'percent' and fill it with 0s
    clean_df['percent'] = 0

    # Iterate through the unique values in f2 and for each value count the amount of f1
    # Find the indexes of each row with a particular value and for each of these row insert count * 100 in the percent column
    for c in featured:
        count = 1 / clean_df[clean_df[f2] == c].count()[f1]
        index_list = clean_df[clean_df[f2] == c].index.tolist()
        for i in index_list:
            clean_df.loc[i, 'percent'] = count * 100

    # Group dataframe by ShipsFromCountry and IsWinner and sum percent
    group = clean_df[['percent',f2,f1]].groupby([f2,f1]).sum()
    
    # Plot values of group in a stacked bar chart
    my_plot = group.unstack().plot(kind='bar', stacked=True, title=f1 + " by " +  f2, figsize=(15,7))

    # Define label colours and text and add to the plot
    red_patch = mpatches.Patch(color='green', label=f1)
    blue_patch = mpatches.Patch(color='blue', label="Not " + f1)
    my_plot.legend(handles=[red_patch, blue_patch], frameon = True)

    # Define x and y labels and min and max values for the y axis
    my_plot.set_xlabel(f2)
    my_plot.set_ylabel("% " + f1)
    my_plot.set_ylim([0,100])

# %%
# Group by day of week and hour of day, get mean 
# hd_delay = df.groupby([df["Timestamp"].dt.dayofweek, df["Timestamp"].dt.hour])["Delay"].mean()

# %%
groups = df.groupby([df["Timestamp"].dt.dayofweek, df["Timestamp"].dt.hour])["Delay"].mean()

# %%
type(groups)

# %%
hourly_delay = df.groupby(['Hour'])["Delay"].mean().plot(figsize=(15,5))

hourly_delay.set(xlabel="Time of Day", ylabel="Delay")
hourly_delay.set_xticks([x for x in range(24)])
hourly_delay.set_xticklabels([x for x in range(24)])

# %%
hourly_delay = df.groupby(['Hour'])["Delay"].mean().plot(figsize=(15,5), kind='bar')

hourly_delay.set(xlabel="Time of Day", ylabel="Delay (seconds)")

# plt.savefig("hourly_delay_bar.png")

# %%
days = df.groupby(["Day"])

# %%
for name, day in days:
    
    hours = day.groupby(["Hour"])["Delay"].mean().plot()
#     hours["Delay"].mean().hist()

# %%
df.groupby["Hour"]

# %%
groups.hist(figsize=(10, 5))

# %%
for group in hd_delay:
    print(group)
    print()
